# %%
import stable_baselines3 as sb3
from stable_baselines3.ppo import PPO
from stable_baselines3.common.policies import ActorCriticPolicy
from stable_baselines3.common.vec_env.dummy_vec_env import DummyVecEnv
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.env_util import make_vec_env
from typing import Type, Optional, Union, Dict, Any, List, Tuple
import numpy as np
import gymnasium as gym
from modifiedPPO import PolicyAnchoredPPO

from dynamic_environments import DynamicFrozenLakeEnv, DynamicEnv, DynamicHalfCheetahEnv
# Out:
# Modified PPO imported

# %%
class PolicyAnchoredPPO(PPO):
    """
    Custom PPO class inheriting from Stable Baselines 3 PPO.
    You can add custom logic for the algorithm by modifying this class.
    """

    def __init__(self, 
                 policy: Union[str, Type[ActorCriticPolicy]], 
                 env: Union[DummyVecEnv, str], 
                 gp_threshold: float,  # Default reward threshold for a "good" policy
                 gp_k: int = 5,        # Max number of good policies to store
                 td_alpha: float = 0.5,       # Alpha value for task change detection
                 learning_rate: Union[float, Any] = 3e-4,
                 n_steps: int = 2048,
                 batch_size: int = 64,
                 n_epochs: int = 10,
                 gamma: float = 0.99,
                 gae_lambda: float = 0.95,
                 clip_range: Union[float, Any] = 0.2,
                 ent_coef: float = 0.0,
                 vf_coef: float = 0.5,
                 max_grad_norm: float = 0.5,
                 verbose: int = 0,
                 tensorboard_log: Optional[str] = None,
                 _init_setup_model: bool = True,
                 **kwargs):
        
        # Initialize the parent PPO class
        super(PolicyAnchoredPPO, self).__init__(policy, env, learning_rate=learning_rate, n_steps=n_steps, 
                                        batch_size=batch_size, n_epochs=n_epochs, gamma=gamma,
                                        gae_lambda=gae_lambda, clip_range=clip_range, ent_coef=ent_coef,
                                        vf_coef=vf_coef, max_grad_norm=max_grad_norm,
                                        verbose=verbose, tensorboard_log=tensorboard_log,
                                        _init_setup_model=_init_setup_model, **kwargs)
        
        self.gp_threshold = gp_threshold  # Reward threshold to consider a policy as "good"
        self.gp_k = gp_k                  # Max number of good policies to store
        self.good_policies: List[Tuple[ActorCriticPolicy, float]] = []  # List of (policy, reward)
        self.td_alpha = td_alpha  # Sensitivity parameter for task change detection
        self.previous_rewards = []  # Buffer to store rewards of the previous training step


    def update_good_policies(self, policy: ActorCriticPolicy, reward: float):
        """
        Check if the policy is a 'good' policy based on the reward and update the list.
        """
        if reward >= self.gp_threshold:
            self.good_policies.append((policy, reward))

            # Sort based on rewards in descending order and keep only top k policies
            self.good_policies.sort(key=lambda x: x[1], reverse=True)
            self.good_policies = self.good_policies[:self.gp_k]

    def detect_task_change(self, current_rewards: List[float]):
        """
        Detect if the task/environment has changed based on reward decline.
        A task change is detected if the current rewards are significantly lower
        than the mean of the previous rewards (by alpha times standard deviation).
        """
        if len(self.previous_rewards) == 0:
            # No previous rewards available to compare, skip detection
            return
        
        # Calculate mean and standard deviation of previous rewards
        prev_mean = np.mean(self.previous_rewards)
        prev_std = np.std(self.previous_rewards)

        # Calculate mean of current rewards
        current_mean = np.mean(current_rewards)

        # Check if there's a sharp decline (current rewards < prev_mean - alpha * prev_std)
        if current_mean < (1 - self.td_alpha) * prev_mean  :
            print(f"Task change detected! Current rewards: {current_mean:.2f}, Previous mean: {prev_mean:.2f}, Std: {prev_std:.2f}")

    def _setup_model(self):
        """
        Override to modify model setup if needed.
        """
        super(PolicyAnchoredPPO, self)._setup_model()

    def train(self):
        """
        Overriding the train method to update the 'good' policies at the end of training iterations.
        """
        super(PolicyAnchoredPPO, self).train()

        # Retrieve accumulated rewards after the training step
        if len(self.ep_info_buffer) == 0:
            raise Warning("Cannot find any episode information in the buffer. Make sure you are using a VecEnv.")
        current_rewards = [ep_info['r'] for ep_info in self.ep_info_buffer]
        accumulated_rewards = np.mean(current_rewards)

        # Detect task change based on reward decline
        self.detect_task_change(current_rewards)

        # Store the current rewards for the next step comparison
        self.previous_rewards = current_rewards

        # Update the good policies based on current policy and accumulated rewards
        self.update_good_policies(self.policy, accumulated_rewards)


    def learn(self, total_timesteps: int, callback: Optional[BaseCallback] = None, 
              log_interval: int = 1, tb_log_name: str = "PPO", 
              reset_num_timesteps: bool = True, progress_bar: bool = False):
        """
        Overriding the learn method to track good policies at the end of each iteration.
        """
        return super(PolicyAnchoredPPO, self).learn(total_timesteps=total_timesteps, 
                                            callback=callback, 
                                            log_interval=log_interval, 
                                            tb_log_name=tb_log_name, 
                                            reset_num_timesteps=reset_num_timesteps,
                                            progress_bar=progress_bar)
    
    def get_good_policies(self):
        """
        Get the current list of good policies and their associated rewards.
        """
        return self.good_policies

# %%
from stable_baselines3.common.monitor import Monitor, load_results
from gymnasium.envs.mujoco.half_cheetah_v4 import HalfCheetahEnv
from modified_gym_envs.ModifiedHalfCheetah import ModifiedHalfCheetahEnv
from gymnasium.wrappers import TimeLimit
# reimport modifiedPPO to get the latest changes
import importlib
import modifiedPPO
import torch
importlib.reload(modifiedPPO)
from modifiedPPO import PolicyAnchoredPPO


max_steps = 2048
env = DynamicHalfCheetahEnv(switch_after=10_000, xml_file=r'./modified_gym_envs\assets\modifiedHalfCheetah.xml')
# env = HalfCheetahEnv()
env = TimeLimit(env, max_episode_steps=max_steps)
env = Monitor(env)
env = make_vec_env(lambda: env, n_envs=1)

# model = PolicyAnchoredPPO("MlpPolicy", env, gp_threshold= 1., verbose=1, td_alpha=0.5)
model = PolicyAnchoredPPO("MlpPolicy", env, verbose=1, n_steps=max_steps, device='cuda', anchor_pol_kl_coef=0, td_alpha=0.5)

model.learn(total_timesteps=10_000)
# Out:
# Modified PPO imported
# Using cuda device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.05e+03 |
# |    ep_rew_mean     | -732     |
# | time/              |          |
# |    fps             | 570      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                 |             |
# |    ep_len_mean           | 2.05e+03    |
# |    ep_rew_mean           | -765        |
# | time/                    |             |
# |    fps                   | 435         |
# |    iterations            | 2           |
# |    time_elapsed          | 9           |
# |    total_timesteps       | 4096        |
# | train/                   |             |
# |    anchor_kl_div         | 0           |
# |    approx_kl             | 0.010234315 |
# |    clip_fraction         | 0.114       |
# |    clip_range            | 0.2         |
# |    entropy_loss          | -8.49       |
# |    explained_variance    | -0.0632     |
# |    learning_rate         | 0.0003      |
# |    loss                  | 5.6         |
# |    n_updates             | 10          |
# |    policy_gradient_loss  | -0.0225     |
# |    policy_loss           | -0.0387     |
# |    policy_loss_div_term  | 0           |
# |    policy_loss_main_term | -0.0387     |
# |    std                   | 0.993       |
# |    value_loss            | 25.4        |
# ------------------------------------------
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 23
#      20 # model = PolicyAnchoredPPO("MlpPolicy", env, gp_threshold= 1., verbose=1, td_alpha=0.5)
#      21 model = PolicyAnchoredPPO("MlpPolicy", env, verbose=1, n_steps=max_steps, device='cuda', anchor_pol_kl_coef=0, td_alpha=0.5)
# ---> 23 model.learn(total_timesteps=10_000)
#
# File c:\Users\patel\OneDrive - iiit-b\Desktop\coursework\sem 7\Topics in AI\code\modifiedPPO.py:368, in PolicyAnchoredPPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     359 def learn(
#     360     self: SelfPPO,
#     361     total_timesteps: int,
#    (...)
#     366     progress_bar: bool = False,
#     367 ) -> SelfPPO:
# --> 368     return super().learn(
#     369         total_timesteps=total_timesteps,
#     370         callback=callback,
#     371         log_interval=log_interval,
#     372         tb_log_name=tb_log_name,
#     373         reset_num_timesteps=reset_num_timesteps,
#     374         progress_bar=progress_bar,
#     375     )
#
# File c:\Users\patel\anaconda3\envs\tiai\Lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:313, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     310         assert self.ep_info_buffer is not None
#     311         self._dump_logs(iteration)
# --> 313     self.train()
#     315 callback.on_training_end()
#     317 return self
#
# File c:\Users\patel\OneDrive - iiit-b\Desktop\coursework\sem 7\Topics in AI\code\modifiedPPO.py:331, in PolicyAnchoredPPO.train(self)
#     328 accumulated_rewards = np.mean(current_rewards)
#     330 self.episodic_rewards.append(accumulated_rewards)
# --> 331 self.detect_task_change(current_rewards)
#     333 self.previous_rewards = current_rewards
#     335 self.update_good_policies(self.policy, accumulated_rewards)
#
# File c:\Users\patel\OneDrive - iiit-b\Desktop\coursework\sem 7\Topics in AI\code\modifiedPPO.py:402, in PolicyAnchoredPPO.detect_task_change(self, current_rewards)
#     400 prev_mean = np.mean(self.previous_rewards)
#     401 prev_std = np.std(self.previous_rewards)
# --> 402 mean_gradient = np.mean(np.diff(self.episodic_rewards) / self._ep_length) * (len(model.episodic_rewards) > 35)
#     404 # Calculate mean of current rewards
#     405 current_mean = np.mean(current_rewards)
#
# NameError: name 'model' is not defined

# %%
import torch

# %%
state = model.env.observation_space.sample()
state = torch.tensor(state, dtype=torch.float32).unsqueeze(0).to(model.device)
_, _, log_prob = model.policy(state)
# help(model.policy)

# %%
torch.exp(log_prob)
# Out:
# tensor([8.6195e-05], device='cuda:0', grad_fn=<ExpBackward0>)

# %%
torch.randint(0, 10, (10,))
# Out:
# tensor([1, 8, 0, 8, 9, 1, 4, 5, 9, 9])

# %%
# np.sample(model.rollout_buffer.observations, )
# sample from the buffer
# model.rollout_buffer.observations)
sampled_ind = torch.randint(0, model.rollout_buffer.observations.shape[0], (300,))
sampled_ind
sampled_obs = model.rollout_buffer.observations[sampled_ind]
sampled_obs.shape
# Out:
# (300, 17)

# %%
sampled_states = np.array([env.observation_space.sample() for _ in range(model.anchor_pol_sample_size)])
# sampled_states = obs_as_tensor(sampled_states, self.device)
sampled_states.shape
# Out:
# (1000, 17)

# %%
np.diff(model.episodic_reward) / 2048 * (len(model.episodic_reward) > 30)
# Out:
# array([0.00697385, 0.00819297, 0.00672582, 0.00718097, 0.0061351 ,
#        0.00329046, 0.00732079, 0.00659191, 0.00625446, 0.00639113,
#        0.00598122, 0.00624605, 0.00597513, 0.00547394, 0.00659235,
#        0.00504996, 0.00582401, 0.00515942, 0.00476905, 0.00499614,
#        0.00460571, 0.00489908, 0.00442436, 0.00505048, 0.00422683,
#        0.00420832, 0.00422823, 0.00117276, 0.00300074, 0.00619415,
#        0.00388048, 0.00480525, 0.00352403, 0.00651133, 0.00465504,
#        0.00467086, 0.00483733, 0.0053742 , 0.00503175, 0.00524553,
#        0.00573963, 0.00631322, 0.00501554, 0.00513943, 0.0050443 ,
#        0.00592736, 0.00454989, 0.00498325])

# %%
model.num_timesteps
# Out:
# 392377

# %%
plotter(env.get_attr('env')[0])
len(env.get_attr('env')[0].get_episode_rewards())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 plotter(env.get_attr('env')[0])
#       2 len(env.get_attr('env')[0].get_episode_rewards())
#
# NameError: name 'plotter' is not defined

# %%
def smoothen(data, window=5):
    return [sum(data[i:i+window])/window for i in range(len(data)-window)]

smooth_data = smoothen(env.get_attr('env')[0].get_episode_rewards())
plotter(env, data=smooth_data)

# %%
import cv2
import IPython.display as display
import ipywidgets as widgets
import time


def render_game_to_cell(obs):
    if obs is None or obs.size == 0:
        print("Empty frame received")
        return
    screen_data = obs
    frame = cv2.cvtColor(screen_data, cv2.COLOR_RGB2BGR)
    _, jpeg = cv2.imencode('.jpeg', frame)
    image_widget.value = jpeg.tobytes()

image_widget = widgets.Image(format='jpeg')
display.display(image_widget)
# Out:
# Image(value=b'', format='jpeg')

# %%
from modified_gym_envs.ModifiedHalfCheetah import HalfCheetahEnv, ModifiedHalfCheetahEnv

test_env = HalfCheetahEnv(render_mode='rgb_array')

obs, _ = test_env.reset()
for i in range(1000):
    action, _states = model.predict(obs)
    obs, rewards, dones, _, info = test_env.step(action)
    render_game_to_cell(test_env.render())
    time.sleep(0.02)
    if dones:
        obs = test_env.reset()
        time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[43], line 10
#       8 obs, rewards, dones, _, info = test_env.step(action)
#       9 render_game_to_cell(test_env.render())
# ---> 10 time.sleep(0.02)
#      11 if dones:
#      12     obs = test_env.reset()
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
def plotter(env=env, data=None):
    if data is not None:
        plt.plot(data)
    else:
        plt.plot(env.get_episode_rewards())
    plt.xlabel('Timesteps(*1000)')
    plt.ylabel('Rewards')
    plt.title('Rewards over Timesteps')
    plt.show()

# env = env.get_attr('env')[0]
plotter(env.get_attr('env')[0])
len(env.get_attr('env')[0].get_episode_rewards())
# Out:
# 397

# %%
max_steps = 1000
env = DynamicHalfCheetahEnv(switch_after=6000, xml_file=r'./modified_gym_envs\assets\modifiedHalfCheetah.xml')
# env = HalfCheetahEnv()
env = TimeLimit(env, max_episode_steps=max_steps)
env = Monitor(env)
env = make_vec_env(lambda: env, n_envs=1)

model = PolicyAnchoredPPO("MlpPolicy", env, gp_threshold= 1., verbose=1, td_alpha=0.5)
# model = PPO("MlpPolicy", env, verbose=1, device='cuda')

model.learn(total_timesteps=15000)
# Out:
# Using cuda device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -318     |
# | time/              |          |
# |    fps             | 515      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -351        |
# | time/                   |             |
# |    fps                  | 422         |
# |    iterations           | 2           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009171408 |
# |    clip_fraction        | 0.0909      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.5        |
# |    explained_variance   | -0.00205    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.3        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0199     |
# |    std                  | 0.997       |
# |    value_loss           | 41.8        |
# -----------------------------------------
# Task change detected! Current rewards: -350.68, Previous mean: -317.90, Std: 65.87
# Switching environment dynamics after 6000 steps.
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -348         |
# | time/                   |              |
# |    fps                  | 405          |
# |    iterations           | 3            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0077887466 |
# |    clip_fraction        | 0.0541       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -8.48        |
# |    explained_variance   | 0.143        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.14         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0154      |
# |    std                  | 0.991        |
# |    value_loss           | 26           |
# ------------------------------------------
# Task change detected! Current rewards: -347.53, Previous mean: -350.68, Std: 60.15
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -339        |
# | time/                   |             |
# |    fps                  | 399         |
# |    iterations           | 4           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.006448188 |
# |    clip_fraction        | 0.04        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.45       |
# |    explained_variance   | 0.138       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.5        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0138     |
# |    std                  | 0.987       |
# |    value_loss           | 34.4        |
# -----------------------------------------
# Task change detected! Current rewards: -339.31, Previous mean: -347.53, Std: 49.37
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -338        |
# | time/                   |             |
# |    fps                  | 391         |
# |    iterations           | 5           |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.010933284 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.41       |
# |    explained_variance   | 0.41        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.21        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0251     |
# |    std                  | 0.981       |
# |    value_loss           | 12.3        |
# -----------------------------------------
# Task change detected! Current rewards: -338.36, Previous mean: -339.31, Std: 45.11
# Switching environment dynamics after 12000 steps.
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -331         |
# | time/                   |              |
# |    fps                  | 388          |
# |    iterations           | 6            |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0076551195 |
# |    clip_fraction        | 0.0523       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -8.4         |
# |    explained_variance   | 0.334        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.7         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0147      |
# |    std                  | 0.98         |
# |    value_loss           | 35.2         |
# ------------------------------------------
# Task change detected! Current rewards: -331.10, Previous mean: -338.36, Std: 42.44
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -329         |
# | time/                   |              |
# |    fps                  | 388          |
# |    iterations           | 7            |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0098172175 |
# |    clip_fraction        | 0.0945       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -8.38        |
# |    explained_variance   | 0.324        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.9         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0207      |
# |    std                  | 0.976        |
# |    value_loss           | 28.9         |
# ------------------------------------------
# Task change detected! Current rewards: -328.57, Previous mean: -331.10, Std: 42.03
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -324        |
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 8           |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.009031266 |
# |    clip_fraction        | 0.0888      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.36       |
# |    explained_variance   | 0.558       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.02        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0205     |
# |    std                  | 0.974       |
# |    value_loss           | 22.2        |
# -----------------------------------------
# Task change detected! Current rewards: -323.79, Previous mean: -328.57, Std: 40.87

# %%
plotter(env.get_attr('env')[0])

# %%
max_steps = 1000
env = DynamicHalfCheetahEnv(switch_after=40000, xml_file=r'./modified_gym_envs\assets\modifiedHalfCheetah.xml')
# env = HalfCheetahEnv()
env = TimeLimit(env, max_episode_steps=max_steps)
env = Monitor(env)
env = make_vec_env(lambda: env, n_envs=1)

model = PolicyAnchoredPPO("MlpPolicy", env, gp_threshold= 1., verbose=1, td_alpha=0.6)
# model = PPO("MlpPolicy", env, verbose=1, device='cuda')

model.learn(total_timesteps=200_000)
plotter(env.get_attr('env')[0])
# Out:
# Using cuda device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -321     |
# | time/              |          |
# |    fps             | 564      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -321       |
# | time/                   |            |
# |    fps                  | 437        |
# |    iterations           | 2          |
# |    time_elapsed         | 9          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.00848886 |
# |    clip_fraction        | 0.0868     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -8.5       |
# |    explained_variance   | -0.0377    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 6.97       |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.0196    |
# |    std                  | 0.995      |
# |    value_loss           | 33.7       |
# ----------------------------------------
# Task change detected! Current rewards: -320.91, Previous mean: -321.46, Std: 47.14
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -336        |
# | time/                   |             |
# |    fps                  | 415         |
# |    iterations           | 3           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.007678043 |
# |    clip_fraction        | 0.0659      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.48       |
# |    explained_variance   | 0.14        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.2        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0178     |
# |    std                  | 0.993       |
# |    value_loss           | 41.6        |
# -----------------------------------------
# Task change detected! Current rewards: -335.94, Previous mean: -320.91, Std: 60.70
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -345         |
# | time/                   |              |
# |    fps                  | 401          |
# |    iterations           | 4            |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0076380484 |
# |    clip_fraction        | 0.0599       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -8.46        |
# |    explained_variance   | 0.174        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.7         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0161      |
# |    std                  | 0.988        |
# |    value_loss           | 35.3         |
# ------------------------------------------
# Task change detected! Current rewards: -344.80, Previous mean: -335.94, Std: 68.23
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -348        |
# | time/                   |             |
# |    fps                  | 395         |
# |    iterations           | 5           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009311294 |
# |    clip_fraction        | 0.0722      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.43       |
# |    explained_variance   | 0.554       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.1        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0182     |
# |    std                  | 0.985       |
# |    value_loss           | 43.3        |
# -----------------------------------------
# Task change detected! Current rewards: -347.76, Previous mean: -344.80, Std: 62.64
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -345        |
# | time/                   |             |
# |    fps                  | 391         |
# |    iterations           | 6           |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.010376114 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.4        |
# |    explained_variance   | 0.259       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.62        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0263     |
# |    std                  | 0.978       |
# |    value_loss           | 25.4        |
# -----------------------------------------
# Task change detected! Current rewards: -345.47, Previous mean: -347.76, Std: 58.80
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -343        |
# | time/                   |             |
# |    fps                  | 389         |
# |    iterations           | 7           |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.012861291 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.37       |
# |    explained_variance   | 0.166       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.42        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0312     |
# |    std                  | 0.975       |
# |    value_loss           | 15.8        |
# -----------------------------------------
# Task change detected! Current rewards: -342.65, Previous mean: -345.47, Std: 53.94
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -342       |
# | time/                   |            |
# |    fps                  | 387        |
# |    iterations           | 8          |
# |    time_elapsed         | 42         |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.01034936 |
# |    clip_fraction        | 0.0956     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -8.34      |
# |    explained_variance   | 0.448      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.23       |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.0235    |
# |    std                  | 0.968      |
# |    value_loss           | 19         |
# ----------------------------------------
# Task change detected! Current rewards: -342.50, Previous mean: -342.65, Std: 51.00
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -336        |
# | time/                   |             |
# |    fps                  | 385         |
# |    iterations           | 9           |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.007770732 |
# |    clip_fraction        | 0.0637      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.32       |
# |    explained_variance   | 0.387       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.17        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0203     |
# |    std                  | 0.968       |
# |    value_loss           | 26.1        |
# -----------------------------------------
# Task change detected! Current rewards: -335.65, Previous mean: -342.50, Std: 47.77
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -329        |
# | time/                   |             |
# |    fps                  | 384         |
# |    iterations           | 10          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.007750057 |
# |    clip_fraction        | 0.0653      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.32       |
# |    explained_variance   | 0.376       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.8        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0194     |
# |    std                  | 0.969       |
# |    value_loss           | 33.3        |
# -----------------------------------------
# Task change detected! Current rewards: -329.45, Previous mean: -335.65, Std: 49.05
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -330        |
# | time/                   |             |
# |    fps                  | 381         |
# |    iterations           | 11          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.010249747 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.3        |
# |    explained_variance   | 0.263       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.8        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0279     |
# |    std                  | 0.963       |
# |    value_loss           | 28.5        |
# -----------------------------------------
# Task change detected! Current rewards: -329.72, Previous mean: -329.45, Std: 58.43
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -331         |
# | time/                   |              |
# |    fps                  | 379          |
# |    iterations           | 12           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0118272845 |
# |    clip_fraction        | 0.12         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -8.27        |
# |    explained_variance   | 0.368        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.01         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.0307      |
# |    std                  | 0.956        |
# |    value_loss           | 16.2         |
# ------------------------------------------
# Task change detected! Current rewards: -331.04, Previous mean: -329.72, Std: 64.91
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -325        |
# | time/                   |             |
# |    fps                  | 378         |
# |    iterations           | 13          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.008278338 |
# |    clip_fraction        | 0.0552      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.24       |
# |    explained_variance   | 0.253       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.58        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0195     |
# |    std                  | 0.953       |
# |    value_loss           | 40.1        |
# -----------------------------------------
# Task change detected! Current rewards: -324.65, Previous mean: -331.04, Std: 63.73
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -321        |
# | time/                   |             |
# |    fps                  | 377         |
# |    iterations           | 14          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.008869749 |
# |    clip_fraction        | 0.0815      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.21       |
# |    explained_variance   | 0.408       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.9        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0239     |
# |    std                  | 0.949       |
# |    value_loss           | 38.1        |
# -----------------------------------------
# Task change detected! Current rewards: -320.98, Previous mean: -324.65, Std: 83.84
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -323        |
# | time/                   |             |
# |    fps                  | 376         |
# |    iterations           | 15          |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.011204543 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.19       |
# |    explained_variance   | 0.394       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.7        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0323     |
# |    std                  | 0.945       |
# |    value_loss           | 20.6        |
# -----------------------------------------
# Task change detected! Current rewards: -323.24, Previous mean: -320.98, Std: 83.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -324        |
# | time/                   |             |
# |    fps                  | 375         |
# |    iterations           | 16          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.010563077 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.15       |
# |    explained_variance   | 0.666       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.63        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0287     |
# |    std                  | 0.938       |
# |    value_loss           | 18.2        |
# -----------------------------------------
# Task change detected! Current rewards: -324.47, Previous mean: -323.24, Std: 81.31
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -327        |
# | time/                   |             |
# |    fps                  | 374         |
# |    iterations           | 17          |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.013555765 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.12       |
# |    explained_variance   | 0.364       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.61        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0374     |
# |    std                  | 0.936       |
# |    value_loss           | 11.8        |
# -----------------------------------------
# Task change detected! Current rewards: -326.60, Previous mean: -324.47, Std: 78.96
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -325        |
# | time/                   |             |
# |    fps                  | 373         |
# |    iterations           | 18          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.010441249 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.1        |
# |    explained_variance   | 0.231       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17          |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0249     |
# |    std                  | 0.93        |
# |    value_loss           | 31.6        |
# -----------------------------------------
# Task change detected! Current rewards: -325.23, Previous mean: -326.60, Std: 78.08
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -328        |
# | time/                   |             |
# |    fps                  | 372         |
# |    iterations           | 19          |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.011015202 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.06       |
# |    explained_variance   | 0.406       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.1        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0314     |
# |    std                  | 0.924       |
# |    value_loss           | 23.1        |
# -----------------------------------------
# Task change detected! Current rewards: -327.90, Previous mean: -325.23, Std: 76.23
# Switching environment dynamics after 40000 steps.
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -328        |
# | time/                   |             |
# |    fps                  | 371         |
# |    iterations           | 20          |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.010029202 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.04       |
# |    explained_variance   | 0.388       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.7        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0274     |
# |    std                  | 0.925       |
# |    value_loss           | 37.8        |
# -----------------------------------------
# Task change detected! Current rewards: -327.96, Previous mean: -327.90, Std: 75.98
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -323        |
# | time/                   |             |
# |    fps                  | 371         |
# |    iterations           | 21          |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.013895494 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.03       |
# |    explained_variance   | 0.217       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.14        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0383     |
# |    std                  | 0.922       |
# |    value_loss           | 17.7        |
# -----------------------------------------
# Task change detected! Current rewards: -322.97, Previous mean: -327.96, Std: 74.64
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -324        |
# | time/                   |             |
# |    fps                  | 370         |
# |    iterations           | 22          |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.011344448 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.99       |
# |    explained_variance   | 0.581       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.65        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0328     |
# |    std                  | 0.914       |
# |    value_loss           | 19.9        |
# -----------------------------------------
# Task change detected! Current rewards: -323.98, Previous mean: -322.97, Std: 75.24
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -323        |
# | time/                   |             |
# |    fps                  | 369         |
# |    iterations           | 23          |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.020376131 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.92       |
# |    explained_variance   | 0.544       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.21        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0453     |
# |    std                  | 0.902       |
# |    value_loss           | 8.7         |
# -----------------------------------------
# Task change detected! Current rewards: -322.89, Previous mean: -323.98, Std: 73.70
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -320        |
# | time/                   |             |
# |    fps                  | 368         |
# |    iterations           | 24          |
# |    time_elapsed         | 133         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.013255637 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.88       |
# |    explained_variance   | 0.653       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.8         |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0363     |
# |    std                  | 0.898       |
# |    value_loss           | 10.7        |
# -----------------------------------------
# Task change detected! Current rewards: -319.65, Previous mean: -322.89, Std: 73.29
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -317       |
# | time/                   |            |
# |    fps                  | 367        |
# |    iterations           | 25         |
# |    time_elapsed         | 139        |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.00852075 |
# |    clip_fraction        | 0.0895     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.87      |
# |    explained_variance   | 0.703      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.51       |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.0258    |
# |    std                  | 0.9        |
# |    value_loss           | 18.6       |
# ----------------------------------------
# Task change detected! Current rewards: -316.94, Previous mean: -319.65, Std: 74.45
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -316        |
# | time/                   |             |
# |    fps                  | 367         |
# |    iterations           | 26          |
# |    time_elapsed         | 144         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.009602912 |
# |    clip_fraction        | 0.0951      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.89       |
# |    explained_variance   | 0.629       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.2        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0262     |
# |    std                  | 0.902       |
# |    value_loss           | 27.3        |
# -----------------------------------------
# Task change detected! Current rewards: -316.12, Previous mean: -316.94, Std: 75.47
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -315        |
# | time/                   |             |
# |    fps                  | 366         |
# |    iterations           | 27          |
# |    time_elapsed         | 150         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.011259804 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.89       |
# |    explained_variance   | 0.591       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.6         |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0312     |
# |    std                  | 0.901       |
# |    value_loss           | 21.7        |
# -----------------------------------------
# Task change detected! Current rewards: -315.26, Previous mean: -316.12, Std: 74.52
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -315        |
# | time/                   |             |
# |    fps                  | 365         |
# |    iterations           | 28          |
# |    time_elapsed         | 156         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.009643104 |
# |    clip_fraction        | 0.0891      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.88       |
# |    explained_variance   | 0.723       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.2        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0262     |
# |    std                  | 0.899       |
# |    value_loss           | 33.1        |
# -----------------------------------------
# Task change detected! Current rewards: -315.34, Previous mean: -315.26, Std: 73.43
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -313        |
# | time/                   |             |
# |    fps                  | 365         |
# |    iterations           | 29          |
# |    time_elapsed         | 162         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.011117246 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.87       |
# |    explained_variance   | 0.427       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.2        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0305     |
# |    std                  | 0.897       |
# |    value_loss           | 36.6        |
# -----------------------------------------
# Task change detected! Current rewards: -313.17, Previous mean: -315.34, Std: 72.58
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -312        |
# | time/                   |             |
# |    fps                  | 365         |
# |    iterations           | 30          |
# |    time_elapsed         | 168         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.010480927 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.84       |
# |    explained_variance   | 0.292       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.7        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0323     |
# |    std                  | 0.893       |
# |    value_loss           | 32.6        |
# -----------------------------------------
# Task change detected! Current rewards: -312.24, Previous mean: -313.17, Std: 74.73
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -308        |
# | time/                   |             |
# |    fps                  | 365         |
# |    iterations           | 31          |
# |    time_elapsed         | 173         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.014754009 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.81       |
# |    explained_variance   | 0.727       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.8        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0383     |
# |    std                  | 0.887       |
# |    value_loss           | 17.2        |
# -----------------------------------------
# Task change detected! Current rewards: -308.32, Previous mean: -312.24, Std: 73.81
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -308         |
# | time/                   |              |
# |    fps                  | 364          |
# |    iterations           | 32           |
# |    time_elapsed         | 179          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0126870265 |
# |    clip_fraction        | 0.145        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.78        |
# |    explained_variance   | 0.508        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.82         |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.0357      |
# |    std                  | 0.884        |
# |    value_loss           | 21.5         |
# ------------------------------------------
# Task change detected! Current rewards: -307.51, Previous mean: -308.32, Std: 75.99
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -306       |
# | time/                   |            |
# |    fps                  | 364        |
# |    iterations           | 33         |
# |    time_elapsed         | 185        |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.01573583 |
# |    clip_fraction        | 0.168      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.77      |
# |    explained_variance   | 0.482      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 9.19       |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.0396    |
# |    std                  | 0.882      |
# |    value_loss           | 19.1       |
# ----------------------------------------
# Task change detected! Current rewards: -306.02, Previous mean: -307.51, Std: 75.05
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -306        |
# | time/                   |             |
# |    fps                  | 364         |
# |    iterations           | 34          |
# |    time_elapsed         | 191         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.016192267 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.74       |
# |    explained_variance   | 0.306       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.83        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0425     |
# |    std                  | 0.878       |
# |    value_loss           | 16.1        |
# -----------------------------------------
# Task change detected! Current rewards: -305.52, Previous mean: -306.02, Std: 74.47
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -304        |
# | time/                   |             |
# |    fps                  | 364         |
# |    iterations           | 35          |
# |    time_elapsed         | 196         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.017118353 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.7        |
# |    explained_variance   | 0.195       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.36        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.042      |
# |    std                  | 0.87        |
# |    value_loss           | 15.4        |
# -----------------------------------------
# Task change detected! Current rewards: -304.33, Previous mean: -305.52, Std: 73.62
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -303        |
# | time/                   |             |
# |    fps                  | 364         |
# |    iterations           | 36          |
# |    time_elapsed         | 202         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.015208667 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.64       |
# |    explained_variance   | 0.335       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.4         |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0411     |
# |    std                  | 0.861       |
# |    value_loss           | 16.3        |
# -----------------------------------------
# Task change detected! Current rewards: -303.03, Previous mean: -304.33, Std: 73.17
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -300        |
# | time/                   |             |
# |    fps                  | 364         |
# |    iterations           | 37          |
# |    time_elapsed         | 208         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.015252808 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.57       |
# |    explained_variance   | 0.274       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.9        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0397     |
# |    std                  | 0.852       |
# |    value_loss           | 19.2        |
# -----------------------------------------
# Task change detected! Current rewards: -300.42, Previous mean: -303.03, Std: 72.58
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -299        |
# | time/                   |             |
# |    fps                  | 363         |
# |    iterations           | 38          |
# |    time_elapsed         | 214         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.015444163 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.54       |
# |    explained_variance   | 0.327       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.39        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0449     |
# |    std                  | 0.849       |
# |    value_loss           | 20.2        |
# -----------------------------------------
# Task change detected! Current rewards: -298.62, Previous mean: -300.42, Std: 73.76
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -297        |
# | time/                   |             |
# |    fps                  | 362         |
# |    iterations           | 39          |
# |    time_elapsed         | 220         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.020501705 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.47       |
# |    explained_variance   | 0.328       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.65        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0496     |
# |    std                  | 0.837       |
# |    value_loss           | 13.2        |
# -----------------------------------------
# Task change detected! Current rewards: -296.91, Previous mean: -298.62, Std: 73.63
# Switching environment dynamics after 80000 steps.
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -295       |
# | time/                   |            |
# |    fps                  | 362        |
# |    iterations           | 40         |
# |    time_elapsed         | 226        |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.02100239 |
# |    clip_fraction        | 0.225      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.43      |
# |    explained_variance   | 0.51       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.05       |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.0526    |
# |    std                  | 0.833      |
# |    value_loss           | 10.2       |
# ----------------------------------------
# Task change detected! Current rewards: -294.70, Previous mean: -296.91, Std: 73.46
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -294        |
# | time/                   |             |
# |    fps                  | 361         |
# |    iterations           | 41          |
# |    time_elapsed         | 231         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.014517065 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.4        |
# |    explained_variance   | 0.239       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.9         |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0377     |
# |    std                  | 0.828       |
# |    value_loss           | 15          |
# -----------------------------------------
# Task change detected! Current rewards: -293.96, Previous mean: -294.70, Std: 73.98
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -291        |
# | time/                   |             |
# |    fps                  | 360         |
# |    iterations           | 42          |
# |    time_elapsed         | 238         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.015113207 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.38       |
# |    explained_variance   | 0.408       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.98        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.045      |
# |    std                  | 0.828       |
# |    value_loss           | 22.6        |
# -----------------------------------------
# Task change detected! Current rewards: -291.18, Previous mean: -293.96, Std: 73.45
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -290        |
# | time/                   |             |
# |    fps                  | 360         |
# |    iterations           | 43          |
# |    time_elapsed         | 244         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.020115932 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.34       |
# |    explained_variance   | 0.417       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.1         |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0479     |
# |    std                  | 0.819       |
# |    value_loss           | 14.9        |
# -----------------------------------------
# Task change detected! Current rewards: -289.98, Previous mean: -291.18, Std: 74.24
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | -290      |
# | time/                   |           |
# |    fps                  | 360       |
# |    iterations           | 44        |
# |    time_elapsed         | 249       |
# |    total_timesteps      | 90112     |
# | train/                  |           |
# |    approx_kl            | 0.0165782 |
# |    clip_fraction        | 0.17      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -7.29     |
# |    explained_variance   | 0.271     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 5.84      |
# |    n_updates            | 430       |
# |    policy_gradient_loss | -0.0449   |
# |    std                  | 0.812     |
# |    value_loss           | 13.5      |
# ---------------------------------------
# Task change detected! Current rewards: -289.74, Previous mean: -289.98, Std: 73.84
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -290        |
# | time/                   |             |
# |    fps                  | 360         |
# |    iterations           | 45          |
# |    time_elapsed         | 255         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.018158834 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.26       |
# |    explained_variance   | 0.0943      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.43        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0465     |
# |    std                  | 0.811       |
# |    value_loss           | 15          |
# -----------------------------------------
# Task change detected! Current rewards: -290.14, Previous mean: -289.74, Std: 73.34
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -288        |
# | time/                   |             |
# |    fps                  | 360         |
# |    iterations           | 46          |
# |    time_elapsed         | 261         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.014702966 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.25       |
# |    explained_variance   | 0.369       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.8        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0421     |
# |    std                  | 0.81        |
# |    value_loss           | 28.6        |
# -----------------------------------------
# Task change detected! Current rewards: -288.21, Previous mean: -290.14, Std: 72.61
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -287        |
# | time/                   |             |
# |    fps                  | 360         |
# |    iterations           | 47          |
# |    time_elapsed         | 267         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.018322347 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.22       |
# |    explained_variance   | 0.349       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.51        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0451     |
# |    std                  | 0.804       |
# |    value_loss           | 14.3        |
# -----------------------------------------
# Task change detected! Current rewards: -287.34, Previous mean: -288.21, Std: 73.08
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -286        |
# | time/                   |             |
# |    fps                  | 359         |
# |    iterations           | 48          |
# |    time_elapsed         | 273         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.014980501 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.18       |
# |    explained_variance   | 0.459       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.38        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0393     |
# |    std                  | 0.798       |
# |    value_loss           | 22.6        |
# -----------------------------------------
# Task change detected! Current rewards: -285.66, Previous mean: -287.34, Std: 72.58
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -284        |
# | time/                   |             |
# |    fps                  | 359         |
# |    iterations           | 49          |
# ...
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -119       |
# | time/                   |            |
# |    fps                  | 357        |
# |    iterations           | 83         |
# |    time_elapsed         | 475        |
# |    total_timesteps      | 169984     |
# | train/                  |            |
# |    approx_kl            | 0.03681919 |
# |    clip_fraction        | 0.324      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.79      |
# |    explained_variance   | 0.21       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.24       |
# |    n_updates            | 820        |
# |    policy_gradient_loss | -0.0576    |
# |    std                  | 0.633      |
# |    value_loss           | 10.4       |
# ----------------------------------------
# Task change detected! Current rewards: -119.34, Previous mean: -126.41, Std: 124.07
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -112        |
# | time/                   |             |
# |    fps                  | 356         |
# |    iterations           | 84          |
# |    time_elapsed         | 481         |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.033214357 |
# |    clip_fraction        | 0.335       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.73       |
# |    explained_variance   | 0.273       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.86        |
# |    n_updates            | 830         |
# |    policy_gradient_loss | -0.0573     |
# |    std                  | 0.628       |
# |    value_loss           | 9.65        |
# -----------------------------------------
# Task change detected! Current rewards: -111.54, Previous mean: -119.34, Std: 124.62
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -106        |
# | time/                   |             |
# |    fps                  | 356         |
# |    iterations           | 85          |
# |    time_elapsed         | 487         |
# |    total_timesteps      | 174080      |
# | train/                  |             |
# |    approx_kl            | 0.021253832 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.69       |
# |    explained_variance   | 0.512       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.06        |
# |    n_updates            | 840         |
# |    policy_gradient_loss | -0.049      |
# |    std                  | 0.624       |
# |    value_loss           | 19.9        |
# -----------------------------------------
# Task change detected! Current rewards: -106.04, Previous mean: -111.54, Std: 124.16
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -102        |
# | time/                   |             |
# |    fps                  | 356         |
# |    iterations           | 86          |
# |    time_elapsed         | 493         |
# |    total_timesteps      | 176128      |
# | train/                  |             |
# |    approx_kl            | 0.021908727 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.66       |
# |    explained_variance   | 0.623       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.6        |
# |    n_updates            | 850         |
# |    policy_gradient_loss | -0.045      |
# |    std                  | 0.621       |
# |    value_loss           | 26.2        |
# -----------------------------------------
# Task change detected! Current rewards: -101.62, Previous mean: -106.04, Std: 123.91
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -95         |
# | time/                   |             |
# |    fps                  | 356         |
# |    iterations           | 87          |
# |    time_elapsed         | 499         |
# |    total_timesteps      | 178176      |
# | train/                  |             |
# |    approx_kl            | 0.020969385 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.63       |
# |    explained_variance   | 0.743       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.2        |
# |    n_updates            | 860         |
# |    policy_gradient_loss | -0.0492     |
# |    std                  | 0.619       |
# |    value_loss           | 18.9        |
# -----------------------------------------
# Task change detected! Current rewards: -95.03, Previous mean: -101.62, Std: 124.60
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -88.6      |
# | time/                   |            |
# |    fps                  | 356        |
# |    iterations           | 88         |
# |    time_elapsed         | 505        |
# |    total_timesteps      | 180224     |
# | train/                  |            |
# |    approx_kl            | 0.02652605 |
# |    clip_fraction        | 0.267      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.59      |
# |    explained_variance   | 0.423      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 9.11       |
# |    n_updates            | 870        |
# |    policy_gradient_loss | -0.0521    |
# |    std                  | 0.613      |
# |    value_loss           | 18.4       |
# ----------------------------------------
# Task change detected! Current rewards: -88.63, Previous mean: -95.03, Std: 126.16
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -80.7       |
# | time/                   |             |
# |    fps                  | 356         |
# |    iterations           | 89          |
# |    time_elapsed         | 510         |
# |    total_timesteps      | 182272      |
# | train/                  |             |
# |    approx_kl            | 0.027678788 |
# |    clip_fraction        | 0.292       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.52       |
# |    explained_variance   | 0.638       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.4        |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.0535     |
# |    std                  | 0.605       |
# |    value_loss           | 18          |
# -----------------------------------------
# Task change detected! Current rewards: -80.68, Previous mean: -88.63, Std: 128.74
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -75.4       |
# | time/                   |             |
# |    fps                  | 356         |
# |    iterations           | 90          |
# |    time_elapsed         | 516         |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.020874588 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.47       |
# |    explained_variance   | 0.669       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.7        |
# |    n_updates            | 890         |
# |    policy_gradient_loss | -0.0459     |
# |    std                  | 0.602       |
# |    value_loss           | 22.1        |
# -----------------------------------------
# Task change detected! Current rewards: -75.38, Previous mean: -80.68, Std: 130.09
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -69.2       |
# | time/                   |             |
# |    fps                  | 356         |
# |    iterations           | 91          |
# |    time_elapsed         | 522         |
# |    total_timesteps      | 186368      |
# | train/                  |             |
# |    approx_kl            | 0.039127443 |
# |    clip_fraction        | 0.346       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.43       |
# |    explained_variance   | 0.303       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.72        |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.0537     |
# |    std                  | 0.598       |
# |    value_loss           | 13.8        |
# -----------------------------------------
# Task change detected! Current rewards: -69.18, Previous mean: -75.38, Std: 131.72
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -62.1       |
# | time/                   |             |
# |    fps                  | 356         |
# |    iterations           | 92          |
# |    time_elapsed         | 528         |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.021360293 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.4        |
# |    explained_variance   | 0.729       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.2        |
# |    n_updates            | 910         |
# |    policy_gradient_loss | -0.0459     |
# |    std                  | 0.596       |
# |    value_loss           | 24.9        |
# -----------------------------------------
# Task change detected! Current rewards: -62.07, Previous mean: -69.18, Std: 130.77
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -53.8      |
# | time/                   |            |
# |    fps                  | 356        |
# |    iterations           | 93         |
# |    time_elapsed         | 533        |
# |    total_timesteps      | 190464     |
# | train/                  |            |
# |    approx_kl            | 0.03166475 |
# |    clip_fraction        | 0.313      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.36      |
# |    explained_variance   | 0.659      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.35       |
# |    n_updates            | 920        |
# |    policy_gradient_loss | -0.0554    |
# |    std                  | 0.591      |
# |    value_loss           | 17.5       |
# ----------------------------------------
# Task change detected! Current rewards: -53.82, Previous mean: -62.07, Std: 131.04
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -44.8      |
# | time/                   |            |
# |    fps                  | 356        |
# |    iterations           | 94         |
# |    time_elapsed         | 539        |
# |    total_timesteps      | 192512     |
# | train/                  |            |
# |    approx_kl            | 0.03077125 |
# |    clip_fraction        | 0.284      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.3       |
# |    explained_variance   | 0.792      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.11       |
# |    n_updates            | 930        |
# |    policy_gradient_loss | -0.0577    |
# |    std                  | 0.585      |
# |    value_loss           | 20.2       |
# ----------------------------------------
# Task change detected! Current rewards: -44.80, Previous mean: -53.82, Std: 129.95
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -37.3       |
# | time/                   |             |
# |    fps                  | 356         |
# |    iterations           | 95          |
# |    time_elapsed         | 545         |
# |    total_timesteps      | 194560      |
# | train/                  |             |
# |    approx_kl            | 0.041925214 |
# |    clip_fraction        | 0.357       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.23       |
# |    explained_variance   | 0.199       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.42        |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.053      |
# |    std                  | 0.578       |
# |    value_loss           | 14.1        |
# -----------------------------------------
# Task change detected! Current rewards: -37.30, Previous mean: -44.80, Std: 127.80
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -27.5       |
# | time/                   |             |
# |    fps                  | 356         |
# |    iterations           | 96          |
# |    time_elapsed         | 551         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.026957747 |
# |    clip_fraction        | 0.266       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.19       |
# |    explained_variance   | 0.58        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.6        |
# |    n_updates            | 950         |
# |    policy_gradient_loss | -0.0483     |
# |    std                  | 0.576       |
# |    value_loss           | 22          |
# -----------------------------------------
# Task change detected! Current rewards: -27.51, Previous mean: -37.30, Std: 129.60
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -20.2      |
# | time/                   |            |
# |    fps                  | 356        |
# |    iterations           | 97         |
# |    time_elapsed         | 556        |
# |    total_timesteps      | 198656     |
# | train/                  |            |
# |    approx_kl            | 0.03920854 |
# |    clip_fraction        | 0.346      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.15      |
# |    explained_variance   | 0.211      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.03       |
# |    n_updates            | 960        |
# |    policy_gradient_loss | -0.0562    |
# |    std                  | 0.571      |
# |    value_loss           | 15.2       |
# ----------------------------------------
# Task change detected! Current rewards: -20.19, Previous mean: -27.51, Std: 131.94
# Switching environment dynamics after 200000 steps.
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -12.4       |
# | time/                   |             |
# |    fps                  | 356         |
# |    iterations           | 98          |
# |    time_elapsed         | 562         |
# |    total_timesteps      | 200704      |
# | train/                  |             |
# |    approx_kl            | 0.031120526 |
# |    clip_fraction        | 0.303       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.08       |
# |    explained_variance   | 0.553       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.05        |
# |    n_updates            | 970         |
# |    policy_gradient_loss | -0.0535     |
# |    std                  | 0.564       |
# |    value_loss           | 20          |
# -----------------------------------------
# Task change detected! Current rewards: -12.43, Previous mean: -20.19, Std: 131.94

# %%
# Create environment
env = gym.make('CartPole-v1')
env = Monitor(env)
env = make_vec_env(lambda: env, n_envs=1)

# Create and train the custom PPO model
model = PolicyAnchoredPPO("MlpPolicy", env, gp_threshold= 200, verbose=1)
model.learn(total_timesteps=10000)

# Access the good policies
good_policies = model.get_good_policies()
print(f"Good policies: {good_policies}")
# Out:
# Using cuda device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22       |
# |    ep_rew_mean     | 22       |
# | time/              |          |
# |    fps             | 547      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27.1        |
# |    ep_rew_mean          | 27.1        |
# | time/                   |             |
# |    fps                  | 434         |
# |    iterations           | 2           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008111546 |
# |    clip_fraction        | 0.0749      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.687      |
# |    explained_variance   | -0.00145    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.41        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 51.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 37.1        |
# |    ep_rew_mean          | 37.1        |
# | time/                   |             |
# |    fps                  | 401         |
# |    iterations           | 3           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009682664 |
# |    clip_fraction        | 0.065       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.669      |
# |    explained_variance   | 0.0897      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.5        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0184     |
# |    value_loss           | 38.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.1        |
# |    ep_rew_mean          | 49.1        |
# | time/                   |             |
# |    fps                  | 388         |
# |    iterations           | 4           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008423384 |
# |    clip_fraction        | 0.0745      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.636      |
# |    explained_variance   | 0.189       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.2        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0192     |
# |    value_loss           | 55.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 61.9        |
# |    ep_rew_mean          | 61.9        |
# | time/                   |             |
# |    fps                  | 382         |
# |    iterations           | 5           |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.005825748 |
# |    clip_fraction        | 0.0572      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.615      |
# |    explained_variance   | 0.249       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.9        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0162     |
# |    value_loss           | 62.6        |
# -----------------------------------------
# Good policies: []

# %%
import time
obs = env.reset()
env.render_mode = 'human'
for _ in range(1000):
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    time.sleep(0.01)
    env.render()

# %% [markdown]
# ## Works For Sparse Rewards?? I'm not sure...
