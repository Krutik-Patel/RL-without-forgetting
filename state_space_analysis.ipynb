# %% [markdown]
# We want to compare the state spaces of both the tasks once the PPO algorithm has converged.

# %%
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy

# %%
env = gym.make('HalfCheetah-v4')

# %%
model = PPO('MlpPolicy', env, verbose=1)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=1_000_000, progress_bar=True)

# %%
model.save("ppo_half_cheetah")

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=10)

print(f"Mean reward: {mean_reward}, Std reward: {std_reward}")
# Out:
# Mean reward: 1682.8620305533782, Std reward: 116.00409815475679

# %%
env = gym.make('HalfCheetah-v3', xml_file="./modified_gym_envs/assets/modifiedHalfCheetah.xml")

# %%
model = PPO('MlpPolicy', env, verbose=1)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=1_000_000, progress_bar=True)
# Out:
# Output()
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -443     |
# | time/              |          |
# |    fps             | 347      |
# |    iterations      | 1        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -378        |
# | time/                   |             |
# |    fps                  | 284         |
# |    iterations           | 2           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009588701 |
# |    clip_fraction        | 0.093       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.52       |
# ...

# %%
model.save("ppo_half_cheetah_2")
