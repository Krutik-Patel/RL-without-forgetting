# %%
import gym
# from gym.envs.toy_text.frozen_lake import FrozenLakeEnv
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env

import frozenlake_env
import importlib
importlib.reload(frozenlake_env)
from frozenlake_env import FrozenLakeEnv
PARAM_DIR = 'params'

def create_custom_env(custom_map, is_slippery=False, render_mode=None):
    """
    Creates a custom Frozen Lake environment.
    
    :param custom_map: List of strings representing the map.
    :param is_slippery: Boolean indicating whether the surface is slippery.
    :return: Custom Frozen Lake environment.
    """
    env = FrozenLakeEnv(desc=custom_map, is_slippery=is_slippery, render_mode=render_mode)
    return env

def train_ppo_on_map(custom_map, total_timesteps=10000, is_slippery=False, pretrained_model_path=None):
    """
    Trains a PPO agent on a custom Frozen Lake map.
    
    :param custom_map: List of strings representing the map.
    :param total_timesteps: Total timesteps for training.
    :param is_slippery: Boolean indicating whether the surface is slippery.
    :return: Trained PPO model.
    """
    # Create the environment
    env = create_custom_env(custom_map, is_slippery)
    env = make_vec_env(lambda: env, n_envs=1)  # Vectorize the environment

    # Initialize the PPO model
    if pretrained_model_path is not None:
        model = PPO.load(pretrained_model_path, env)
    else:
        model = PPO("MlpPolicy", env, verbose=1)

    # Train the model
    model.learn(total_timesteps=total_timesteps)

    return model

# Example usage with the baseline map
baseline_map = [
    'SFFF',
    'FHFH',
    'FFFH',
    'HFFG'
]

# Train the PPO agent on the baseline map
trained_model = train_ppo_on_map(baseline_map, total_timesteps=50000)

# Save the model
trained_model.save(f"{PARAM_DIR}/ppo_frozenlake_baseline")
# Out:
# Using cuda device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 7.97     |
# |    ep_rew_mean     | 0.03     |
# | time/              |          |
# |    fps             | 583      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.79        |
# |    ep_rew_mean          | 0.04        |
# | time/                   |             |
# |    fps                  | 468         |
# |    iterations           | 2           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.019345885 |
# |    clip_fraction        | 0.397       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -0.008      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0512     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0237     |
# |    value_loss           | 0.0197      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.9         |
# |    ep_rew_mean          | 0.07        |
# | time/                   |             |
# |    fps                  | 443         |
# |    iterations           | 3           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.015540034 |
# |    clip_fraction        | 0.274       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.0342      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00912     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0166     |
# |    value_loss           | 0.0327      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.61        |
# |    ep_rew_mean          | 0.08        |
# | time/                   |             |
# |    fps                  | 432         |
# |    iterations           | 4           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.011347963 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.212       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00484    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0172     |
# |    value_loss           | 0.0433      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.96        |
# |    ep_rew_mean          | 0.16        |
# | time/                   |             |
# |    fps                  | 425         |
# |    iterations           | 5           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.015775502 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.345       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0464      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0307     |
# |    value_loss           | 0.0643      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.37        |
# |    ep_rew_mean          | 0.3         |
# | time/                   |             |
# |    fps                  | 420         |
# |    iterations           | 6           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.019248944 |
# |    clip_fraction        | 0.302       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.308       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00712     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0452     |
# |    value_loss           | 0.109       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.13        |
# |    ep_rew_mean          | 0.5         |
# | time/                   |             |
# |    fps                  | 418         |
# |    iterations           | 7           |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.027856397 |
# |    clip_fraction        | 0.337       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.954      |
# |    explained_variance   | 0.299       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0192     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.053      |
# |    value_loss           | 0.133       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.21        |
# |    ep_rew_mean          | 0.59        |
# | time/                   |             |
# |    fps                  | 416         |
# |    iterations           | 8           |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.021987516 |
# |    clip_fraction        | 0.24        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.801      |
# |    explained_variance   | 0.233       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00207     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0389     |
# |    value_loss           | 0.141       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.16        |
# |    ep_rew_mean          | 0.78        |
# | time/                   |             |
# |    fps                  | 415         |
# |    iterations           | 9           |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.016802594 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.667      |
# |    explained_variance   | 0.159       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0202      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0289     |
# |    value_loss           | 0.126       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.16        |
# |    ep_rew_mean          | 0.83        |
# | time/                   |             |
# |    fps                  | 414         |
# |    iterations           | 10          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.009166611 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.557      |
# |    explained_variance   | 0.107       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.021       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0216     |
# |    value_loss           | 0.0959      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.43        |
# |    ep_rew_mean          | 0.91        |
# | time/                   |             |
# |    fps                  | 413         |
# |    iterations           | 11          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.007722546 |
# |    clip_fraction        | 0.0983      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.477      |
# |    explained_variance   | 0.0929      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0275      |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0189     |
# |    value_loss           | 0.0726      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.4          |
# |    ep_rew_mean          | 0.97         |
# | time/                   |              |
# |    fps                  | 412          |
# |    iterations           | 12           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0060044457 |
# |    clip_fraction        | 0.0766       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.451       |
# |    explained_variance   | 0.0405       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0197      |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.0126      |
# |    value_loss           | 0.036        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.61        |
# |    ep_rew_mean          | 0.93        |
# | time/                   |             |
# |    fps                  | 412         |
# |    iterations           | 13          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.007979472 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.441      |
# |    explained_variance   | 0.0455      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00754     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00993    |
# |    value_loss           | 0.0253      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.35       |
# |    ep_rew_mean          | 0.98       |
# | time/                   |            |
# |    fps                  | 411        |
# |    iterations           | 14         |
# |    time_elapsed         | 69         |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.02970891 |
# |    clip_fraction        | 0.183      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.358     |
# |    explained_variance   | 0.0518     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0213    |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.0132    |
# |    value_loss           | 0.0311     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.25        |
# |    ep_rew_mean          | 0.97        |
# | time/                   |             |
# |    fps                  | 411         |
# |    iterations           | 15          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.005449698 |
# |    clip_fraction        | 0.0452      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.3        |
# |    explained_variance   | 0.0643      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00207    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00373    |
# |    value_loss           | 0.0108      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.02         |
# |    ep_rew_mean          | 0.96         |
# | time/                   |              |
# |    fps                  | 410          |
# |    iterations           | 16           |
# |    time_elapsed         | 79           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0030722704 |
# |    clip_fraction        | 0.0405       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.249       |
# |    explained_variance   | 0.0851       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0147      |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00574     |
# |    value_loss           | 0.00649      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.13         |
# |    ep_rew_mean          | 1            |
# | time/                   |              |
# |    fps                  | 410          |
# |    iterations           | 17           |
# |    time_elapsed         | 84           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0064810915 |
# |    clip_fraction        | 0.0483       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.216       |
# |    explained_variance   | 0.0597       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0485       |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00534     |
# |    value_loss           | 0.0156       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.27        |
# |    ep_rew_mean          | 0.99        |
# | time/                   |             |
# |    fps                  | 408         |
# |    iterations           | 18          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.024433054 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.234      |
# |    explained_variance   | 0.0712      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0185     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | 0.00361     |
# |    value_loss           | 0.00687     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.15        |
# |    ep_rew_mean          | 0.99        |
# | time/                   |             |
# |    fps                  | 407         |
# |    iterations           | 19          |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.004433089 |
# |    clip_fraction        | 0.0562      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.221      |
# |    explained_variance   | 0.07        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00499    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00765    |
# |    value_loss           | 0.00667     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.17        |
# |    ep_rew_mean          | 0.99        |
# | time/                   |             |
# |    fps                  | 407         |
# |    iterations           | 20          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.003081108 |
# |    clip_fraction        | 0.0559      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.196      |
# |    explained_variance   | 0.0785      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00923    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00226    |
# |    value_loss           | 0.00585     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.09        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 407         |
# |    iterations           | 21          |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.003244404 |
# |    clip_fraction        | 0.0564      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.194      |
# |    explained_variance   | 0.0677      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00827     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | 0.00321     |
# |    value_loss           | 0.00501     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.06        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 407         |
# |    iterations           | 22          |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.023578942 |
# |    clip_fraction        | 0.069       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.182      |
# |    explained_variance   | 0.822       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0228      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | 0.0047      |
# |    value_loss           | 3.79e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.04        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 407         |
# |    iterations           | 23          |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.007674746 |
# |    clip_fraction        | 0.0779      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.163      |
# |    explained_variance   | 0.137       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00809    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | 0.0113      |
# |    value_loss           | 0.00265     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.06         |
# |    ep_rew_mean          | 1            |
# | time/                   |              |
# |    fps                  | 406          |
# |    iterations           | 24           |
# |    time_elapsed         | 120          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0026182118 |
# |    clip_fraction        | 0.0607       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.164       |
# |    explained_variance   | 0.0581       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00865      |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00394     |
# |    value_loss           | 0.0071       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.08         |
# |    ep_rew_mean          | 1            |
# | time/                   |              |
# |    fps                  | 404          |
# |    iterations           | 25           |
# |    time_elapsed         | 126          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0038414067 |
# |    clip_fraction        | 0.0666       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.151       |
# |    explained_variance   | 0.964        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00103      |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.000905    |
# |    value_loss           | 4.2e-05      |
# ------------------------------------------

# %%
import pickle
maps = pickle.load(open("maps.pkl", "rb"))
maps
# Out:
# {'Baseline': ['SFFF', 'FHFH', 'FFFH', 'HFFG'],
#  'Map 2.1': ['SFFF', 'FHFH', 'FFFH', 'HFGF'],
#  'Map 2.2': ['SFFF', 'FHFH', 'FGFH', 'HFFF'],
#  'Map 2.3': ['SFFG', 'FHFH', 'FFFH', 'HFFF'],
#  'Map 3.1': ['SFFF', 'HHFH', 'FHFH', 'HFFG'],
#  'Map 3.2': ['SFFF', 'FHHH', 'FFFF', 'HHFG'],
#  'Map 3.3': ['SFFH', 'HFFF', 'FFHH', 'HFFG'],
#  'Map 4.1': ['FFFS', 'HFHF', 'FHHF', 'GFFF'],
#  'Map 4.2': ['FFFG', 'HFHF', 'HHFF', 'SFFF'],
#  'Map 4.3': ['FFFF', 'FHHS', 'FHFH', 'FFFG'],
#  'Map 5.1': ['FFFFS', 'HFFFH', 'FFHFH', 'HFHFH', 'HGFFF'],
#  'Map 5.2': ['FFFFFG', 'FFFHHF', 'FHFFFF', 'HFFHFF', 'HHFFFH', 'FSFFFF'],
#  'Map 5.3': ['HFG', 'HFH', 'FFS']}

# %%
pretrained_model_path = "ppo_frozenlake_baseline.zip"
trained_model2 = train_ppo_on_map(maps['Map 2.1'], total_timesteps=50000, pretrained_model_path=pretrained_model_path)
trained_model2.save("ppo_frozenlake_map2.1")
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.01     |
# |    ep_rew_mean     | 1        |
# | time/              |          |
# |    fps             | 540      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 5             |
# |    ep_rew_mean          | 1             |
# | time/                   |               |
# |    fps                  | 436           |
# |    iterations           | 2             |
# |    time_elapsed         | 9             |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 0.00028061357 |
# |    clip_fraction        | 0.00381       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0195       |
# |    explained_variance   | 0.0965        |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00137      |
# |    n_updates            | 260           |
# |    policy_gradient_loss | -0.00144      |
# |    value_loss           | 0.00205       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 5             |
# |    ep_rew_mean          | 1             |
# | time/                   |               |
# |    fps                  | 412           |
# |    iterations           | 3             |
# |    time_elapsed         | 14            |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 0.00016061636 |
# |    clip_fraction        | 0.0022        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.017        |
# |    explained_variance   | 0.524         |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.000133     |
# |    n_updates            | 270           |
# |    policy_gradient_loss | -3.61e-05     |
# |    value_loss           | 4.48e-06      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.02        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 401         |
# |    iterations           | 4           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.069966264 |
# |    clip_fraction        | 0.0239      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0341     |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0513     |
# |    n_updates            | 280         |
# |    policy_gradient_loss | 0.0031      |
# |    value_loss           | 3.35e-09    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5            |
# |    ep_rew_mean          | 1            |
# | time/                   |              |
# |    fps                  | 395          |
# |    iterations           | 5            |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0005490081 |
# |    clip_fraction        | 0.011        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.11        |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000179    |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.000269    |
# |    value_loss           | 6.9e-07      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 388         |
# |    iterations           | 6           |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.026382457 |
# |    clip_fraction        | 0.0478      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0572     |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0254      |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00224    |
# |    value_loss           | 4.35e-09    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5            |
# |    ep_rew_mean          | 1            |
# | time/                   |              |
# |    fps                  | 386          |
# |    iterations           | 7            |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0021803905 |
# |    clip_fraction        | 0.0061       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0363      |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000336     |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.000856    |
# |    value_loss           | 1.36e-07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 384         |
# |    iterations           | 8           |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.028838575 |
# |    clip_fraction        | 0.0517      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0711     |
# |    explained_variance   | 0.115       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0269     |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00305    |
# |    value_loss           | 0.00172     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.01        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 383         |
# |    iterations           | 9           |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.001351784 |
# |    clip_fraction        | 0.0164      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.097      |
# |    explained_variance   | 0.63        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00214    |
# |    n_updates            | 330         |
# |    policy_gradient_loss | 0.00168     |
# |    value_loss           | 2.7e-06     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 382         |
# |    iterations           | 10          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.028384067 |
# |    clip_fraction        | 0.0268      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0393     |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0238     |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00264    |
# |    value_loss           | 5.28e-08    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 5             |
# |    ep_rew_mean          | 1             |
# | time/                   |               |
# |    fps                  | 381           |
# |    iterations           | 11            |
# |    time_elapsed         | 59            |
# |    total_timesteps      | 22528         |
# | train/                  |               |
# |    approx_kl            | 0.00015113788 |
# |    clip_fraction        | 0.00371       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.028        |
# |    explained_variance   | 1             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.000679      |
# |    n_updates            | 350           |
# |    policy_gradient_loss | -0.000385     |
# |    value_loss           | 7.51e-11      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 5             |
# |    ep_rew_mean          | 1             |
# | time/                   |               |
# |    fps                  | 380           |
# |    iterations           | 12            |
# |    time_elapsed         | 64            |
# |    total_timesteps      | 24576         |
# | train/                  |               |
# |    approx_kl            | 0.00081369554 |
# |    clip_fraction        | 0.00332       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0234       |
# |    explained_variance   | 0.0889        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00145       |
# |    n_updates            | 360           |
# |    policy_gradient_loss | -0.000817     |
# |    value_loss           | 0.00206       |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.99        |
# |    ep_rew_mean          | 0.99        |
# | time/                   |             |
# |    fps                  | 380         |
# |    iterations           | 13          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.043618973 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.113      |
# |    explained_variance   | 0.825       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0637     |
# |    n_updates            | 370         |
# |    policy_gradient_loss | 0.0537      |
# |    value_loss           | 1.67e-06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5.01         |
# |    ep_rew_mean          | 1            |
# | time/                   |              |
# |    fps                  | 379          |
# |    iterations           | 14           |
# |    time_elapsed         | 75           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0017090763 |
# |    clip_fraction        | 0.0265       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.107       |
# |    explained_variance   | 0.117        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00836      |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00516     |
# |    value_loss           | 0.00169      |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 378        |
# |    iterations           | 15         |
# |    time_elapsed         | 81         |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.05748685 |
# |    clip_fraction        | 0.0253     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0516    |
# |    explained_variance   | 0.916      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0251    |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.0106    |
# |    value_loss           | 4.02e-06   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.01        |
# |    ep_rew_mean          | 0.99        |
# | time/                   |             |
# |    fps                  | 377         |
# |    iterations           | 16          |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.046699613 |
# |    clip_fraction        | 0.0682      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0851     |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.044      |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0051     |
# |    value_loss           | 3.94e-09    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.2         |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 377         |
# |    iterations           | 17          |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.018115593 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.175      |
# |    explained_variance   | 0.0891      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0588      |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00695    |
# |    value_loss           | 0.00204     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.06       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 376        |
# |    iterations           | 18         |
# |    time_elapsed         | 97         |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.01394823 |
# |    clip_fraction        | 0.256      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.175     |
# |    explained_variance   | 0.387      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0236    |
# |    n_updates            | 420        |
# |    policy_gradient_loss | -0.0275    |
# |    value_loss           | 0.0016     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 376         |
# |    iterations           | 19          |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.050078724 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.088      |
# |    explained_variance   | -1.83       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00955    |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0329     |
# |    value_loss           | 0.000156    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 376         |
# |    iterations           | 20          |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.042688616 |
# |    clip_fraction        | 0.027       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0419     |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00213     |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00372    |
# |    value_loss           | 5.19e-08    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.78       |
# |    ep_rew_mean          | 0.99       |
# | time/                   |            |
# |    fps                  | 376        |
# |    iterations           | 21         |
# |    time_elapsed         | 114        |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.10349553 |
# |    clip_fraction        | 0.131      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.134     |
# |    explained_variance   | 1          |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0838    |
# |    n_updates            | 450        |
# |    policy_gradient_loss | -0.0091    |
# |    value_loss           | 2.14e-10   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.53        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 375         |
# |    iterations           | 22          |
# |    time_elapsed         | 119         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.031464346 |
# |    clip_fraction        | 0.468       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.416      |
# |    explained_variance   | 0.0925      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0295     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0664     |
# |    value_loss           | 0.00421     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.32        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 375         |
# |    iterations           | 23          |
# |    time_elapsed         | 125         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.025249556 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.291      |
# |    explained_variance   | 0.123       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0932     |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0452     |
# |    value_loss           | 0.00166     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.07        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 375         |
# |    iterations           | 24          |
# |    time_elapsed         | 130         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.026570652 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.198      |
# |    explained_variance   | 0.822       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0654     |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0475     |
# |    value_loss           | 3.04e-05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 375        |
# |    iterations           | 25         |
# |    time_elapsed         | 136        |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.03349903 |
# |    clip_fraction        | 0.123      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.129     |
# |    explained_variance   | 0.98       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0392    |
# |    n_updates            | 490        |
# |    policy_gradient_loss | -0.043     |
# |    value_loss           | 3.38e-06   |
# ----------------------------------------

# %%
pretrained_model_path = "ppo_frozenlake_map2.1"
trained_model2 = train_ppo_on_map(maps['Map 2.2'], total_timesteps=50000, pretrained_model_path=pretrained_model_path)
trained_model2.save("ppo_frozenlake_map2.2")
pretrained_model_path = "ppo_frozenlake_map2.2"
trained_model2 = train_ppo_on_map(maps['Map 2.3'], total_timesteps=50000, pretrained_model_path=pretrained_model_path)
trained_model2.save("ppo_frozenlake_map2.3")
# Out:
# c:\Users\patel\anaconda3\envs\llama\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 81.9     |
# |    ep_rew_mean     | 0.167    |
# | time/              |          |
# |    fps             | 552      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 161         |
# |    ep_rew_mean          | 0.15        |
# | time/                   |             |
# |    fps                  | 439         |
# |    iterations           | 2           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.002729432 |
# |    clip_fraction        | 0.0315      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.247      |
# |    explained_variance   | -0.837      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00227     |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0115     |
# |    value_loss           | 0.00756     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 161          |
# |    ep_rew_mean          | 0.15         |
# | time/                   |              |
# |    fps                  | 409          |
# |    iterations           | 3            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0007648007 |
# |    clip_fraction        | 0.0142       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.221       |
# |    explained_variance   | -0.217       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00401     |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00193     |
# |    value_loss           | 0.00208      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 161          |
# |    ep_rew_mean          | 0.15         |
# | time/                   |              |
# |    fps                  | 397          |
# |    iterations           | 4            |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0015071986 |
# |    clip_fraction        | 0.0296       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.171       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000251    |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.000786    |
# |    value_loss           | 0.000115     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 437         |
# |    ep_rew_mean          | 0.143       |
# | time/                   |             |
# |    fps                  | 388         |
# |    iterations           | 5           |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.004188545 |
# |    clip_fraction        | 0.0365      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.117      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000614   |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.00116    |
# |    value_loss           | 7.97e-05    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 437           |
# |    ep_rew_mean          | 0.143         |
# | time/                   |               |
# |    fps                  | 381           |
# |    iterations           | 6             |
# |    time_elapsed         | 32            |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 0.00078439753 |
# |    clip_fraction        | 0.0134        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.121        |
# |    explained_variance   | -0.0823       |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.0239       |
# |    n_updates            | 550           |
# |    policy_gradient_loss | -0.00091      |
# |    value_loss           | 0.000361      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 437          |
# |    ep_rew_mean          | 0.143        |
# | time/                   |              |
# |    fps                  | 378          |
# |    iterations           | 7            |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0031498193 |
# |    clip_fraction        | 0.0229       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.075       |
# |    explained_variance   | 3.08e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00106     |
# |    n_updates            | 560          |
# |    policy_gradient_loss | -0.000825    |
# |    value_loss           | 3.94e-05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 437           |
# |    ep_rew_mean          | 0.143         |
# | time/                   |               |
# |    fps                  | 376           |
# |    iterations           | 8             |
# |    time_elapsed         | 43            |
# |    total_timesteps      | 16384         |
# | train/                  |               |
# |    approx_kl            | 9.2064234e-05 |
# |    clip_fraction        | 0.00449       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0616       |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 9.89e-05      |
# |    n_updates            | 570           |
# |    policy_gradient_loss | 0.000413      |
# |    value_loss           | 2.87e-05      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 437         |
# |    ep_rew_mean          | 0.143       |
# | time/                   |             |
# |    fps                  | 372         |
# |    iterations           | 9           |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.000734078 |
# |    clip_fraction        | 0.00825     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0498     |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000556   |
# |    n_updates            | 580         |
# |    policy_gradient_loss | 0.000142    |
# |    value_loss           | 1.9e-05     |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 803           |
# |    ep_rew_mean          | 0.13          |
# | time/                   |               |
# |    fps                  | 371           |
# |    iterations           | 10            |
# |    time_elapsed         | 55            |
# |    total_timesteps      | 20480         |
# | train/                  |               |
# |    approx_kl            | 0.00020626563 |
# |    clip_fraction        | 0.00264       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0483       |
# |    explained_variance   | -0.543        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.000382      |
# |    n_updates            | 590           |
# |    policy_gradient_loss | -0.000113     |
# |    value_loss           | 1.36e-05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 803          |
# |    ep_rew_mean          | 0.13         |
# | time/                   |              |
# |    fps                  | 369          |
# |    iterations           | 11           |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0002068526 |
# |    clip_fraction        | 0.00674      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0613      |
# |    explained_variance   | -1.7         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -9.08e-05    |
# |    n_updates            | 600          |
# |    policy_gradient_loss | -0.00192     |
# |    value_loss           | 9.7e-05      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 803           |
# |    ep_rew_mean          | 0.13          |
# | time/                   |               |
# |    fps                  | 366           |
# |    iterations           | 12            |
# |    time_elapsed         | 67            |
# |    total_timesteps      | 24576         |
# | train/                  |               |
# |    approx_kl            | 0.00038295152 |
# |    clip_fraction        | 0.00635       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0504       |
# |    explained_variance   | -0.000859     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2e-06         |
# |    n_updates            | 610           |
# |    policy_gradient_loss | -0.000315     |
# |    value_loss           | 5.66e-06      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 803          |
# |    ep_rew_mean          | 0.13         |
# | time/                   |              |
# |    fps                  | 362          |
# |    iterations           | 13           |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0002967519 |
# |    clip_fraction        | 0.00684      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0382      |
# |    explained_variance   | -1.01e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.79e-06     |
# |    n_updates            | 620          |
# |    policy_gradient_loss | -0.000308    |
# |    value_loss           | 4.21e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 803          |
# |    ep_rew_mean          | 0.13         |
# | time/                   |              |
# |    fps                  | 359          |
# |    iterations           | 14           |
# |    time_elapsed         | 79           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0003600455 |
# |    clip_fraction        | 0.0043       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0315      |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.93e-07     |
# |    n_updates            | 630          |
# |    policy_gradient_loss | 8.55e-05     |
# |    value_loss           | 3.12e-06     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 803           |
# |    ep_rew_mean          | 0.13          |
# | time/                   |               |
# |    fps                  | 356           |
# |    iterations           | 15            |
# |    time_elapsed         | 86            |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 0.00025935308 |
# |    clip_fraction        | 0.00454       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0231       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.5e-07       |
# |    n_updates            | 640           |
# |    policy_gradient_loss | -0.000118     |
# |    value_loss           | 2.14e-06      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.1e+03       |
# |    ep_rew_mean          | 0.214         |
# | time/                   |               |
# |    fps                  | 355           |
# |    iterations           | 16            |
# |    time_elapsed         | 92            |
# |    total_timesteps      | 32768         |
# | train/                  |               |
# |    approx_kl            | 0.00025478908 |
# |    clip_fraction        | 0.00298       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0301       |
# |    explained_variance   | -1.31         |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.0181       |
# |    n_updates            | 650           |
# |    policy_gradient_loss | 5.42e-05      |
# |    value_loss           | 1.68e-06      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 0.242       |
# | time/                   |             |
# |    fps                  | 354         |
# |    iterations           | 17          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.000462199 |
# |    clip_fraction        | 0.00625     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0411     |
# |    explained_variance   | 0.666       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.35e-07    |
# |    n_updates            | 660         |
# |    policy_gradient_loss | -0.00369    |
# |    value_loss           | 0.000657    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 0.242        |
# | time/                   |              |
# |    fps                  | 354          |
# |    iterations           | 18           |
# |    time_elapsed         | 103          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0020394116 |
# |    clip_fraction        | 0.0128       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0452      |
# |    explained_variance   | 0.547        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00235      |
# |    n_updates            | 670          |
# |    policy_gradient_loss | -0.00898     |
# |    value_loss           | 0.000609     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | 0.242         |
# | time/                   |               |
# |    fps                  | 355           |
# |    iterations           | 19            |
# |    time_elapsed         | 109           |
# |    total_timesteps      | 38912         |
# | train/                  |               |
# |    approx_kl            | 0.00011436074 |
# |    clip_fraction        | 0.00254       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0324       |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.16e-07      |
# |    n_updates            | 680           |
# |    policy_gradient_loss | -7.83e-05     |
# |    value_loss           | 5.07e-07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.04e+03     |
# |    ep_rew_mean          | 0.308        |
# | time/                   |              |
# |    fps                  | 355          |
# |    iterations           | 20           |
# |    time_elapsed         | 115          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0001547061 |
# |    clip_fraction        | 0.00386      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0339      |
# |    explained_variance   | -0.525       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -7.84e-07    |
# |    n_updates            | 690          |
# |    policy_gradient_loss | -0.0016      |
# |    value_loss           | 3.83e-07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.04e+03    |
# |    ep_rew_mean          | 0.308       |
# | time/                   |             |
# |    fps                  | 355         |
# |    iterations           | 21          |
# |    time_elapsed         | 120         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.002144449 |
# |    clip_fraction        | 0.0144      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0402     |
# |    explained_variance   | 0.859       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000699   |
# |    n_updates            | 700         |
# |    policy_gradient_loss | -0.00608    |
# |    value_loss           | 0.000662    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3            |
# |    ep_rew_mean          | 1            |
# | time/                   |              |
# |    fps                  | 356          |
# |    iterations           | 22           |
# |    time_elapsed         | 126          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0002542272 |
# |    clip_fraction        | 0.00254      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0241      |
# |    explained_variance   | -0.719       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -4.89e-06    |
# |    n_updates            | 710          |
# |    policy_gradient_loss | 0.00122      |
# |    value_loss           | 1.62e-07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3           |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 355         |
# |    iterations           | 23          |
# |    time_elapsed         | 132         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.001164993 |
# |    clip_fraction        | 0.00381     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0188     |
# |    explained_variance   | 0.938       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00293    |
# |    n_updates            | 720         |
# |    policy_gradient_loss | -0.00286    |
# |    value_loss           | 0.000727    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 6.27      |
# |    ep_rew_mean          | 1         |
# | time/                   |           |
# |    fps                  | 356       |
# |    iterations           | 24        |
# |    time_elapsed         | 137       |
# |    total_timesteps      | 49152     |
# | train/                  |           |
# |    approx_kl            | 0.2493999 |
# |    clip_fraction        | 0.147     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.111    |
# |    explained_variance   | -0.0823   |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0458   |
# |    n_updates            | 730       |
# |    policy_gradient_loss | -0.0215   |
# |    value_loss           | 1.59e-06  |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.52       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 356        |
# |    iterations           | 25         |
# |    time_elapsed         | 143        |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.04155246 |
# |    clip_fraction        | 0.44       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.529     |
# |    explained_variance   | 0.0526     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0767    |
# |    n_updates            | 740        |
# |    policy_gradient_loss | -0.0616    |
# |    value_loss           | 0.000817   |
# ----------------------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 561  |
# |    iterations      | 1    |
# |    time_elapsed    | 3    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 442          |
# |    iterations           | 2            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0021616858 |
# |    clip_fraction        | 0.0122       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.062       |
# |    explained_variance   | -130         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00239     |
# |    n_updates            | 760          |
# |    policy_gradient_loss | -0.000278    |
# |    value_loss           | 0.000547     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 413           |
# |    iterations           | 3             |
# |    time_elapsed         | 14            |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 0.00059475855 |
# |    clip_fraction        | 0.00957       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0676       |
# |    explained_variance   | -0.205        |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00331      |
# |    n_updates            | 770           |
# |    policy_gradient_loss | 0.000669      |
# |    value_loss           | 1.99e-07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 399           |
# |    iterations           | 4             |
# |    time_elapsed         | 20            |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 0.00047641908 |
# |    clip_fraction        | 0.00889       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0557       |
# |    explained_variance   | 0.0165        |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.000444     |
# |    n_updates            | 780           |
# |    policy_gradient_loss | -0.000756     |
# |    value_loss           | 1.86e-07      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 391          |
# |    iterations           | 5            |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0003294201 |
# |    clip_fraction        | 0.00547      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0527      |
# |    explained_variance   | -0.00359     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00246     |
# |    n_updates            | 790          |
# |    policy_gradient_loss | -0.000379    |
# |    value_loss           | 1.06e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 387          |
# |    iterations           | 6            |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0006144445 |
# |    clip_fraction        | 0.0064       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0611      |
# |    explained_variance   | 0.0193       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00026     |
# |    n_updates            | 800          |
# |    policy_gradient_loss | -0.000535    |
# |    value_loss           | 7.18e-08     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 384           |
# |    iterations           | 7             |
# |    time_elapsed         | 37            |
# |    total_timesteps      | 14336         |
# | train/                  |               |
# |    approx_kl            | 0.00050072477 |
# |    clip_fraction        | 0.00767       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0505       |
# |    explained_variance   | -0.00144      |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.000357     |
# |    n_updates            | 810           |
# |    policy_gradient_loss | -0.000376     |
# |    value_loss           | 5.72e-08      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 381          |
# |    iterations           | 8            |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0002777141 |
# |    clip_fraction        | 0.00293      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0522      |
# |    explained_variance   | 0.00226      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.69e-05     |
# |    n_updates            | 820          |
# |    policy_gradient_loss | -0.000176    |
# |    value_loss           | 3.07e-08     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 379           |
# |    iterations           | 9             |
# |    time_elapsed         | 48            |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 0.00018774663 |
# |    clip_fraction        | 0.00313       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0389       |
# |    explained_variance   | 0.00947       |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.000593     |
# |    n_updates            | 830           |
# |    policy_gradient_loss | -0.000187     |
# |    value_loss           | 3.03e-08      |
# -------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 378            |
# |    iterations           | 10             |
# |    time_elapsed         | 54             |
# |    total_timesteps      | 20480          |
# | train/                  |                |
# |    approx_kl            | 0.000111145986 |
# |    clip_fraction        | 0.00366        |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -0.0431        |
# |    explained_variance   | -0.00269       |
# |    learning_rate        | 0.0003         |
# |    loss                 | 3.4e-05        |
# |    n_updates            | 840            |
# |    policy_gradient_loss | -0.000736      |
# |    value_loss           | 3.56e-08       |
# --------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 377           |
# |    iterations           | 11            |
# |    time_elapsed         | 59            |
# |    total_timesteps      | 22528         |
# | train/                  |               |
# |    approx_kl            | 0.00035281168 |
# |    clip_fraction        | 0.00547       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0334       |
# |    explained_variance   | -0.00938      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.000706      |
# |    n_updates            | 850           |
# |    policy_gradient_loss | -0.00067      |
# |    value_loss           | 1.73e-08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 376           |
# |    iterations           | 12            |
# |    time_elapsed         | 65            |
# |    total_timesteps      | 24576         |
# | train/                  |               |
# |    approx_kl            | 0.00019323255 |
# |    clip_fraction        | 0.00308       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0246       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | -2.04e-07     |
# |    n_updates            | 860           |
# |    policy_gradient_loss | -0.0001       |
# |    value_loss           | 1.16e-08      |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 375         |
# |    iterations           | 13          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.007071178 |
# |    clip_fraction        | 0.0319      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.032      |
# |    explained_variance   | 0.435       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0106     |
# |    n_updates            | 870         |
# |    policy_gradient_loss | 0.0258      |
# |    value_loss           | 1.35e-08    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 374          |
# |    iterations           | 14           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0012455779 |
# |    clip_fraction        | 0.00586      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0175      |
# |    explained_variance   | -0.583       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -5.04e-08    |
# |    n_updates            | 880          |
# |    policy_gradient_loss | 0.00387      |
# |    value_loss           | 2.05e-07     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 373           |
# |    iterations           | 15            |
# |    time_elapsed         | 82            |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 0.00078950124 |
# |    clip_fraction        | 0.0105        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0264       |
# |    explained_variance   | -0.0193       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 9.03e-08      |
# |    n_updates            | 890           |
# |    policy_gradient_loss | -0.000782     |
# |    value_loss           | 1.68e-08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 373           |
# |    iterations           | 16            |
# |    time_elapsed         | 87            |
# |    total_timesteps      | 32768         |
# | train/                  |               |
# |    approx_kl            | 0.00026293518 |
# |    clip_fraction        | 0.00171       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0122       |
# |    explained_variance   | -0.00567      |
# |    learning_rate        | 0.0003        |
# |    loss                 | -6.48e-07     |
# |    n_updates            | 900           |
# |    policy_gradient_loss | -0.000193     |
# |    value_loss           | 5.16e-09      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 371           |
# |    iterations           | 17            |
# |    time_elapsed         | 93            |
# |    total_timesteps      | 34816         |
# | train/                  |               |
# |    approx_kl            | 2.3724919e-05 |
# |    clip_fraction        | 4.88e-05      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0104       |
# |    explained_variance   | -2.19e-05     |
# |    learning_rate        | 0.0003        |
# |    loss                 | -2.77e-07     |
# |    n_updates            | 910           |
# |    policy_gradient_loss | -3.37e-05     |
# |    value_loss           | 6.55e-09      |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 371         |
# |    iterations           | 18          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.000169587 |
# |    clip_fraction        | 0.00122     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0141     |
# |    explained_variance   | -0.0104     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -1.43e-06   |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.000155   |
# |    value_loss           | 4.54e-08    |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 371       |
# |    iterations           | 19        |
# |    time_elapsed         | 104       |
# |    total_timesteps      | 38912     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.0132   |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | -3.05e-06 |
# |    n_updates            | 930       |
# |    policy_gradient_loss | 9.86e-06  |
# |    value_loss           | 8.38e-08  |
# ---------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 370           |
# |    iterations           | 20            |
# |    time_elapsed         | 110           |
# |    total_timesteps      | 40960         |
# | train/                  |               |
# |    approx_kl            | 0.00015958434 |
# |    clip_fraction        | 0.000879      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.021        |
# |    explained_variance   | -10.8         |
# |    learning_rate        | 0.0003        |
# |    loss                 | -4.84e-07     |
# |    n_updates            | 940           |
# |    policy_gradient_loss | -0.00129      |
# |    value_loss           | 1.11e-07      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 370          |
# |    iterations           | 21           |
# |    time_elapsed         | 116          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 6.917433e-05 |
# |    clip_fraction        | 0.002        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0297      |
# |    explained_variance   | -0.00137     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000528     |
# |    n_updates            | 950          |
# |    policy_gradient_loss | 0.000577     |
# |    value_loss           | 7.37e-08     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 370         |
# |    iterations           | 22          |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.007336424 |
# |    clip_fraction        | 0.00952     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0309     |
# |    explained_variance   | -0.85       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0312     |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.0016     |
# |    value_loss           | 3.49e-09    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 370          |
# |    iterations           | 23           |
# |    time_elapsed         | 127          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0010301227 |
# |    clip_fraction        | 0.00771      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0517      |
# |    explained_variance   | 0.177        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00562     |
# |    n_updates            | 970          |
# |    policy_gradient_loss | -0.00153     |
# |    value_loss           | 1.32e-09     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 369         |
# |    iterations           | 24          |
# |    time_elapsed         | 132         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.012935249 |
# |    clip_fraction        | 0.0807      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0914     |
# |    explained_variance   | 0.652       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0188     |
# |    n_updates            | 980         |
# |    policy_gradient_loss | 0.0256      |
# |    value_loss           | 3.19e-06    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 369          |
# |    iterations           | 25           |
# |    time_elapsed         | 138          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0006313459 |
# |    clip_fraction        | 0.00967      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0493      |
# |    explained_variance   | -3.86        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.12e-06     |
# |    n_updates            | 990          |
# |    policy_gradient_loss | 0.00156      |
# |    value_loss           | 3.05e-11     |
# ------------------------------------------

# %% [markdown]
# ## Generate GIF

# %%
import imageio
from stable_baselines3.common.vec_env import DummyVecEnv


def generate_gif_from_policy(model, custom_map, gif_filename="ppo_frozenlake.gif", is_slippery=False):
    # Create the environment
    def _init():
        env = gym.make("FrozenLake-v1", desc=custom_map, is_slippery=is_slippery, render_mode='rgb_array')
        return env
    env = DummyVecEnv([_init])
    obs = env.reset()

    # List to hold frames
    frames = []

    # Run the agent in the environment
    for _ in range(100):  # Set a limit to prevent infinite loops
        frames.append(env.render())
        action, _ = model.predict(obs)
        obs, _, done, _ = env.step(action)
        if done:
            break

    # Create the GIF
    imageio.mimsave(gif_filename, frames, duration=0.3)
    print(f"GIF saved as {gif_filename}")

# Example usage with the baseline map and trained model
baseline_map = maps['Baseline']
map_21 = maps['Map 2.1']
map_22 = maps['Map 2.2']
map_23 = maps['Map 2.3']
map_31 = maps['Map 3.1']
map_32 = maps['Map 3.2']
map_33 = maps['Map 3.3']
map_41 = maps['Map 4.1']
map_42 = maps['Map 4.2']
map_43 = maps['Map 4.3']

# Load the trained model

# Generate the GIF
trained_model = PPO.load("ppo_frozenlake_Map 3.1")
# generate_gif_from_policy(trained_model, baseline_map, gif_filename="ppo_frozenlake_baseline.gif")
# generate_gif_from_policy(trained_model, map_21, gif_filename="ppo_frozenlake_map2.1.gif")
# generate_gif_from_policy(trained_model, map_22, gif_filename="ppo_frozenlake_map2.2.gif")
generate_gif_from_policy(trained_model, map_23, gif_filename="ppo_frozenlake_map3.1.gif")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[25], line 43
#      38 map_43 = maps['Map 4.3']
#      40 # Load the trained model
#      41
#      42 # Generate the GIF
# ---> 43 trained_model = PPO.load("ppo_frozenlake_Map 3.1")
#      44 # generate_gif_from_policy(trained_model, baseline_map, gif_filename="ppo_frozenlake_baseline.gif")
#      45 # generate_gif_from_policy(trained_model, map_21, gif_filename="ppo_frozenlake_map2.1.gif")
#      46 # generate_gif_from_policy(trained_model, map_22, gif_filename="ppo_frozenlake_map2.2.gif")
#      47 generate_gif_from_policy(trained_model, map_23, gif_filename="ppo_frozenlake_map3.1.gif")
#
# File c:\Users\patel\anaconda3\envs\llama\Lib\site-packages\stable_baselines3\common\base_class.py:680, in BaseAlgorithm.load(cls, path, env, device, custom_objects, print_system_info, force_reset, **kwargs)
#     677     print("== CURRENT SYSTEM INFO ==")
#     678     get_system_info()
# --> 680 data, params, pytorch_variables = load_from_zip_file(
#     681     path,
#     682     device=device,
#     683     custom_objects=custom_objects,
#     684     print_system_info=print_system_info,
#     685 )
#     687 assert data is not None, "No data found in the saved file"
#     688 assert params is not None, "No params found in the saved file"
#
# File c:\Users\patel\anaconda3\envs\llama\Lib\site-packages\stable_baselines3\common\save_util.py:403, in load_from_zip_file(load_path, load_data, custom_objects, device, verbose, print_system_info)
#     376 def load_from_zip_file(
#     377     load_path: Union[str, pathlib.Path, io.BufferedIOBase],
#     378     load_data: bool = True,
#    (...)
#     382     print_system_info: bool = False,
#     383 ) -> Tuple[Optional[Dict[str, Any]], TensorDict, Optional[TensorDict]]:
#     384     """
#     385     Load model data from a .zip archive
#     386
#    (...)
#     401         and dict of pytorch variables
#     402     """
# --> 403     file = open_path(load_path, "r", verbose=verbose, suffix="zip")
#     405     # set device to cpu if cuda is not available
#     406     device = get_device(device=device)
#
# File c:\Users\patel\anaconda3\envs\llama\Lib\functools.py:909, in singledispatch.<locals>.wrapper(*args, **kw)
#     905 if not args:
#     906     raise TypeError(f'{funcname} requires at least '
#     907                     '1 positional argument')
# --> 909 return dispatch(args[0].__class__)(*args, **kw)
#
# File c:\Users\patel\anaconda3\envs\llama\Lib\site-packages\stable_baselines3\common\save_util.py:240, in open_path_str(path, mode, verbose, suffix)
#     225 @open_path.register(str)
#     226 def open_path_str(path: str, mode: str, verbose: int = 0, suffix: Optional[str] = None) -> io.BufferedIOBase:
#     227     """
#     228     Open a path given by a string. If writing to the path, the function ensures
#     229     that the path exists.
#    (...)
#     238     :return:
#     239     """
# --> 240     return open_path_pathlib(pathlib.Path(path), mode, verbose, suffix)
#
# File c:\Users\patel\anaconda3\envs\llama\Lib\site-packages\stable_baselines3\common\save_util.py:291, in open_path_pathlib(path, mode, verbose, suffix)
#     285         path.parent.mkdir(exist_ok=True, parents=True)
#     287 # if opening was successful uses the open_path() function
#     288 # if opening failed with IsADirectory|FileNotFound, calls open_path_pathlib
#     289 #   with corrections
#     290 # if reading failed with FileNotFoundError, calls open_path_pathlib with suffix
# --> 291 return open_path_pathlib(path, mode, verbose, suffix)
#
# File c:\Users\patel\anaconda3\envs\llama\Lib\site-packages\stable_baselines3\common\save_util.py:272, in open_path_pathlib(path, mode, verbose, suffix)
#     270             path, suffix = newpath, None
#     271         else:
# --> 272             raise error
#     273 else:
#     274     try:
#
# File c:\Users\patel\anaconda3\envs\llama\Lib\site-packages\stable_baselines3\common\save_util.py:264, in open_path_pathlib(path, mode, verbose, suffix)
#     262 if mode == "r":
#     263     try:
# --> 264         return open_path(path.open("rb"), mode, verbose, suffix)
#     265     except FileNotFoundError as error:
#     266         if suffix is not None and suffix != "":
#
# File c:\Users\patel\anaconda3\envs\llama\Lib\pathlib.py:1044, in Path.open(self, mode, buffering, encoding, errors, newline)
#    1042 if "b" not in mode:
#    1043     encoding = io.text_encoding(encoding)
# -> 1044 return io.open(self, mode, buffering, encoding, errors, newline)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ppo_frozenlake_Map 3.1.zip'

# %%
for map_ in maps:
    trained_model = train_ppo_on_map(maps[map_], total_timesteps=50000)
    trained_model.save(f"{PARAM_DIR}/ppo_frozenlake_{map_}")
# Out:
# Using cuda device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 7.39     |
# |    ep_rew_mean     | 0.01     |
# | time/              |          |
# |    fps             | 210      |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.75        |
# |    ep_rew_mean          | 0.01        |
# | time/                   |             |
# |    fps                  | 161         |
# |    iterations           | 2           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.020369183 |
# |    clip_fraction        | 0.469       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -0.0511     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00169     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0384     |
# |    value_loss           | 0.0161      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.17        |
# |    ep_rew_mean          | 0.01        |
# | time/                   |             |
# |    fps                  | 151         |
# |    iterations           | 3           |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.013536868 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.0653      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0224     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0104     |
# |    value_loss           | 0.0208      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.33        |
# |    ep_rew_mean          | 0.08        |
# | time/                   |             |
# |    fps                  | 146         |
# |    iterations           | 4           |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.013216762 |
# |    clip_fraction        | 0.249       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.215       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0102      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0139     |
# |    value_loss           | 0.0315      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.45        |
# |    ep_rew_mean          | 0.09        |
# | time/                   |             |
# |    fps                  | 144         |
# |    iterations           | 5           |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.011274283 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.268       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0212     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0131     |
# |    value_loss           | 0.0573      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.13         |
# |    ep_rew_mean          | 0.11         |
# | time/                   |              |
# |    fps                  | 141          |
# |    iterations           | 6            |
# |    time_elapsed         | 86           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0071508535 |
# |    clip_fraction        | 0.158        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.12        |
# |    explained_variance   | 0.382        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.009        |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0195      |
# |    value_loss           | 0.0709       |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.83       |
# |    ep_rew_mean          | 0.17       |
# | time/                   |            |
# |    fps                  | 139        |
# |    iterations           | 7          |
# |    time_elapsed         | 102        |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.01863167 |
# |    clip_fraction        | 0.195      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.02      |
# |    explained_variance   | 0.352      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0121     |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.035     |
# |    value_loss           | 0.0962     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.83        |
# |    ep_rew_mean          | 0.51        |
# | time/                   |             |
# |    fps                  | 138         |
# |    iterations           | 8           |
# |    time_elapsed         | 118         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.022330455 |
# |    clip_fraction        | 0.261       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.908      |
# |    explained_variance   | 0.354       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0118     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0487     |
# |    value_loss           | 0.121       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.02       |
# |    ep_rew_mean          | 0.62       |
# | time/                   |            |
# |    fps                  | 138        |
# |    iterations           | 9          |
# |    time_elapsed         | 132        |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.02220741 |
# |    clip_fraction        | 0.258      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.791     |
# |    explained_variance   | 0.288      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0159     |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.0481    |
# |    value_loss           | 0.138      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.03        |
# |    ep_rew_mean          | 0.72        |
# | time/                   |             |
# |    fps                  | 138         |
# |    iterations           | 10          |
# |    time_elapsed         | 147         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.022134371 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.651      |
# |    explained_variance   | 0.197       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0139      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0394     |
# |    value_loss           | 0.112       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.6         |
# |    ep_rew_mean          | 0.86        |
# | time/                   |             |
# |    fps                  | 137         |
# |    iterations           | 11          |
# |    time_elapsed         | 163         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.010422167 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.546      |
# |    explained_variance   | 0.0756      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0112      |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0241     |
# |    value_loss           | 0.0879      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.18        |
# |    ep_rew_mean          | 0.88        |
# | time/                   |             |
# |    fps                  | 136         |
# |    iterations           | 12          |
# |    time_elapsed         | 179         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.010271572 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.48       |
# |    explained_variance   | 0.0824      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00698    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0161     |
# |    value_loss           | 0.0569      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.26         |
# |    ep_rew_mean          | 0.92         |
# | time/                   |              |
# |    fps                  | 136          |
# |    iterations           | 13           |
# |    time_elapsed         | 194          |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0054471623 |
# |    clip_fraction        | 0.0977       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.409       |
# |    explained_variance   | 0.0853       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0217       |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.0155      |
# |    value_loss           | 0.0435       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.34         |
# |    ep_rew_mean          | 0.95         |
# | time/                   |              |
# |    fps                  | 136          |
# |    iterations           | 14           |
# |    time_elapsed         | 209          |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0078070024 |
# |    clip_fraction        | 0.0946       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.367       |
# |    explained_variance   | 0.0512       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00293      |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.0123      |
# |    value_loss           | 0.0442       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.17        |
# |    ep_rew_mean          | 0.93        |
# | time/                   |             |
# |    fps                  | 136         |
# |    iterations           | 15          |
# |    time_elapsed         | 224         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.014720303 |
# |    clip_fraction        | 0.0922      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.335      |
# |    explained_variance   | 0.0562      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00222     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00837    |
# |    value_loss           | 0.0285      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.05         |
# |    ep_rew_mean          | 0.97         |
# | time/                   |              |
# |    fps                  | 136          |
# |    iterations           | 16           |
# |    time_elapsed         | 239          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0050016167 |
# |    clip_fraction        | 0.0779       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.276       |
# |    explained_variance   | 0.0742       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00318     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00827     |
# |    value_loss           | 0.0216       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.39        |
# |    ep_rew_mean          | 0.98        |
# | time/                   |             |
# |    fps                  | 136         |
# |    iterations           | 17          |
# |    time_elapsed         | 255         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.011381483 |
# |    clip_fraction        | 0.0824      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.284      |
# |    explained_variance   | 0.0168      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0091     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | 0.00126     |
# |    value_loss           | 0.0061      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.24        |
# |    ep_rew_mean          | 0.98        |
# | time/                   |             |
# |    fps                  | 136         |
# |    iterations           | 18          |
# |    time_elapsed         | 269         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.009853344 |
# |    clip_fraction        | 0.079       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.26       |
# |    explained_variance   | 0.0642      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0107      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00485    |
# |    value_loss           | 0.0116      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.12         |
# |    ep_rew_mean          | 0.99         |
# | time/                   |              |
# |    fps                  | 137          |
# |    iterations           | 19           |
# |    time_elapsed         | 283          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0069268006 |
# |    clip_fraction        | 0.06         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.236       |
# |    explained_variance   | 0.0969       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00517      |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00295     |
# |    value_loss           | 0.00423      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.08        |
# |    ep_rew_mean          | 0.99        |
# | time/                   |             |
# |    fps                  | 137         |
# |    iterations           | 20          |
# |    time_elapsed         | 298         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.008637819 |
# |    clip_fraction        | 0.0716      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.208      |
# |    explained_variance   | 0.0782      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0043     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0016     |
# |    value_loss           | 0.0046      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.11         |
# |    ep_rew_mean          | 1            |
# | time/                   |              |
# |    fps                  | 137          |
# |    iterations           | 21           |
# |    time_elapsed         | 313          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0033654857 |
# |    clip_fraction        | 0.0609       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.21        |
# |    explained_variance   | 0.167        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00397     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | 0.00371      |
# |    value_loss           | 0.00198      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.27         |
# |    ep_rew_mean          | 0.99         |
# | time/                   |              |
# |    fps                  | 136          |
# |    iterations           | 22           |
# |    time_elapsed         | 329          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0073230537 |
# |    clip_fraction        | 0.0481       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.195       |
# |    explained_variance   | 0.137        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.009       |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.000212    |
# |    value_loss           | 0.00297      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.12        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 136         |
# |    iterations           | 23          |
# |    time_elapsed         | 345         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.004727656 |
# |    clip_fraction        | 0.0425      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.2        |
# |    explained_variance   | 0.103       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0134     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00854    |
# |    value_loss           | 0.00435     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.17         |
# |    ep_rew_mean          | 0.99         |
# | time/                   |              |
# |    fps                  | 135          |
# |    iterations           | 24           |
# |    time_elapsed         | 362          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0053342665 |
# |    clip_fraction        | 0.0694       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.196       |
# |    explained_variance   | 0.929        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00385     |
# |    n_updates            | 230          |
# |    policy_gradient_loss | 0.00656      |
# |    value_loss           | 6.48e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.03        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 135         |
# |    iterations           | 25          |
# |    time_elapsed         | 378         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.008038804 |
# |    clip_fraction        | 0.0648      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.185      |
# |    explained_variance   | 0.114       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00719     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00633    |
# |    value_loss           | 0.0035      |
# -----------------------------------------
# Using cuda device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.7      |
# |    ep_rew_mean     | 0.01     |
# | time/              |          |
# |    fps             | 211      |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10.1       |
# |    ep_rew_mean          | 0.03       |
# | time/                   |            |
# |    fps                  | 167        |
# |    iterations           | 2          |
# |    time_elapsed         | 24         |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.02037197 |
# |    clip_fraction        | 0.4        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.37      |
# |    explained_variance   | -0.00222   |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0151    |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.0408    |
# |    value_loss           | 0.0846     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13.1        |
# |    ep_rew_mean          | 0.01        |
# | time/                   |             |
# |    fps                  | 151         |
# |    iterations           | 3           |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.013536556 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | -0.0469     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0492     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0132     |
# |    value_loss           | 0.0151      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21.4        |
# |    ep_rew_mean          | 0.02        |
# | time/                   |             |
# |    fps                  | 151         |
# |    iterations           | 4           |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.013595468 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | -0.0138     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0395      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0198     |
# |    value_loss           | 0.00521     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 25.4         |
# |    ep_rew_mean          | 0.02         |
# | time/                   |              |
# |    fps                  | 150          |
# |    iterations           | 5            |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0132316835 |
# |    clip_fraction        | 0.086        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.00626      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0184      |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0034      |
# |    value_loss           | 0.00833      |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 27.2       |
# |    ep_rew_mean          | 0.01       |
# | time/                   |            |
# |    fps                  | 149        |
# |    iterations           | 6          |
# |    time_elapsed         | 82         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.01572875 |
# |    clip_fraction        | 0.22       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.14      |
# |    explained_variance   | 0.0224     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0133    |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.0093    |
# |    value_loss           | 0.00427    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 38.4         |
# |    ep_rew_mean          | 0            |
# | time/                   |              |
# |    fps                  | 146          |
# |    iterations           | 7            |
# |    time_elapsed         | 97           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0070236763 |
# |    clip_fraction        | 0.107        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | -0.269       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0258      |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0186      |
# |    value_loss           | 0.000171     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 52.7       |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 146        |
# |    iterations           | 8          |
# |    time_elapsed         | 112        |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.00705158 |
# |    clip_fraction        | 0.112      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.04      |
# |    explained_variance   | -0.45      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00179   |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.0154    |
# |    value_loss           | 2.67e-05   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 70.2         |
# |    ep_rew_mean          | 0            |
# | time/                   |              |
# |    fps                  | 145          |
# |    iterations           | 9            |
# |    time_elapsed         | 126          |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0036057336 |
# |    clip_fraction        | 0.118        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | -0.69        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00619     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.0116      |
# |    value_loss           | 9.66e-06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 87.8        |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 144         |
# |    iterations           | 10          |
# |    time_elapsed         | 141         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.004561693 |
# |    clip_fraction        | 0.0697      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.946      |
# |    explained_variance   | -0.643      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0211     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00746    |
# |    value_loss           | 2.73e-06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 104         |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 144         |
# |    iterations           | 11          |
# |    time_elapsed         | 156         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.005217475 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.88       |
# |    explained_variance   | -1.7        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0275      |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00699    |
# |    value_loss           | 6.18e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 121         |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 143         |
# |    iterations           | 12          |
# |    time_elapsed         | 171         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.005896897 |
# |    clip_fraction        | 0.0456      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.888      |
# |    explained_variance   | -1.46       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00758    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00205    |
# |    value_loss           | 0.000173    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 141         |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 142         |
# |    iterations           | 13          |
# |    time_elapsed         | 187         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.010059557 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.899      |
# |    explained_variance   | -6.41       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0126     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00504    |
# |    value_loss           | 2.16e-06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 158         |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 142         |
# |    iterations           | 14          |
# |    time_elapsed         | 201         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.008573355 |
# |    clip_fraction        | 0.074       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.865      |
# |    explained_variance   | -2.7        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000653   |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00209    |
# |    value_loss           | 4.62e-06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 177         |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 142         |
# |    iterations           | 15          |
# |    time_elapsed         | 216         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.016382543 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.923      |
# |    explained_variance   | -15.6       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0174     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00423    |
# |    value_loss           | 6.23e-06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 203         |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 141         |
# |    iterations           | 16          |
# |    time_elapsed         | 231         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.009871177 |
# |    clip_fraction        | 0.0791      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.902      |
# |    explained_variance   | -47         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0204      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.000826   |
# |    value_loss           | 0.000765    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 211        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 140        |
# |    iterations           | 17         |
# |    time_elapsed         | 247        |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.04579013 |
# |    clip_fraction        | 0.229      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.902     |
# |    explained_variance   | -8.27      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0164    |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.00535   |
# |    value_loss           | 0.000323   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 244         |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 140         |
# |    iterations           | 18          |
# |    time_elapsed         | 262         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.026568538 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.862      |
# |    explained_variance   | -6.44       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00967     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.000828   |
# |    value_loss           | 9.22e-06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 252          |
# |    ep_rew_mean          | 0            |
# | time/                   |              |
# |    fps                  | 140          |
# |    iterations           | 19           |
# |    time_elapsed         | 277          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0138973445 |
# |    clip_fraction        | 0.133        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.884       |
# |    explained_variance   | -0.136       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0047      |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.000265    |
# |    value_loss           | 6.42e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 252          |
# |    ep_rew_mean          | 0            |
# | time/                   |              |
# |    fps                  | 140          |
# |    iterations           | 20           |
# |    time_elapsed         | 291          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0031595305 |
# |    clip_fraction        | 0.2          |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.87        |
# |    explained_variance   | -0.138       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0202      |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00221     |
# |    value_loss           | 0.0038       |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 252        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 140        |
# |    iterations           | 21         |
# |    time_elapsed         | 306        |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.01110613 |
# |    clip_fraction        | 0.149      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.847     |
# |    explained_variance   | -11        |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0151     |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.000234  |
# |    value_loss           | 7.24e-07   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 317          |
# |    ep_rew_mean          | 0            |
# | time/                   |              |
# |    fps                  | 140          |
# |    iterations           | 22           |
# |    time_elapsed         | 321          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0036259498 |
# |    clip_fraction        | 0.263        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.855       |
# |    explained_variance   | -1.05        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00439     |
# |    n_updates            | 210          |
# |    policy_gradient_loss | 0.00184      |
# |    value_loss           | 3.14e-07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 317         |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 139         |
# |    iterations           | 23          |
# |    time_elapsed         | 337         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.009106066 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.882      |
# |    explained_variance   | -0.0396     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0278     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00136    |
# |    value_loss           | 1.19e-06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 359         |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 139         |
# |    iterations           | 24          |
# |    time_elapsed         | 352         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.021429308 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.896      |
# |    explained_variance   | -1.51       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00422     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.000451   |
# |    value_loss           | 0.000105    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 368         |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 139         |
# |    iterations           | 25          |
# |    time_elapsed         | 366         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.011501549 |
# |    clip_fraction        | 0.0951      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.971      |
# |    explained_variance   | -0.0633     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00633     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00729    |
# |    value_loss           | 5.91e-06    |
# -----------------------------------------
# Using cuda device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.61     |
# |    ep_rew_mean     | 0.15     |
# | time/              |          |
# |    fps             | 159      |
# |    iterations      | 1        |
# |    time_elapsed    | 12       |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.65        |
# |    ep_rew_mean          | 0.1         |
# | time/                   |             |
# |    fps                  | 133         |
# |    iterations           | 2           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.019270567 |
# |    clip_fraction        | 0.323       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -0.0364     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0112     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0297     |
# |    value_loss           | 0.0767      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.52        |
# |    ep_rew_mean          | 0.18        |
# | time/                   |             |
# |    fps                  | 132         |
# |    iterations           | 3           |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.016099477 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.128       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.02        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0314     |
# |    value_loss           | 0.0893      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.21        |
# |    ep_rew_mean          | 0.33        |
# | time/                   |             |
# |    fps                  | 130         |
# |    iterations           | 4           |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.018006472 |
# |    clip_fraction        | 0.273       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.0926      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00451     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0464     |
# |    value_loss           | 0.12        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.89        |
# |    ep_rew_mean          | 0.54        |
# | time/                   |             |
# |    fps                  | 129         |
# |    iterations           | 5           |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.019367054 |
# |    clip_fraction        | 0.315       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.107       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.033       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0536     |
# |    value_loss           | 0.163       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.81        |
# |    ep_rew_mean          | 0.88        |
# | time/                   |             |
# |    fps                  | 129         |
# |    iterations           | 6           |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.024562284 |
# |    clip_fraction        | 0.28        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.11        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.062       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0511     |
# |    value_loss           | 0.17        |
# -----------------------------------------
# ...
# |    explained_variance   | -0.181       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00688     |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00184     |
# |    value_loss           | 3.43e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 191          |
# |    ep_rew_mean          | 0            |
# | time/                   |              |
# |    fps                  | 11           |
# |    iterations           | 14           |
# |    time_elapsed         | 2522         |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0031655647 |
# |    clip_fraction        | 0.0305       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.685       |
# |    explained_variance   | -0.176       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.02         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | 0.000578     |
# |    value_loss           | 0.000308     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 211          |
# |    ep_rew_mean          | 0            |
# | time/                   |              |
# |    fps                  | 12           |
# |    iterations           | 15           |
# |    time_elapsed         | 2527         |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0057084053 |
# |    clip_fraction        | 0.0528       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.626       |
# |    explained_variance   | -0.222       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00107      |
# |    n_updates            | 140          |
# |    policy_gradient_loss | 0.000683     |
# |    value_loss           | 0.00018      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 229          |
# |    ep_rew_mean          | 0            |
# | time/                   |              |
# |    fps                  | 12           |
# |    iterations           | 16           |
# |    time_elapsed         | 2533         |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0058529032 |
# |    clip_fraction        | 0.0593       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.614       |
# |    explained_variance   | -0.28        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00771     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | 1.88e-05     |
# |    value_loss           | 2.99e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 247         |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 17          |
# |    time_elapsed         | 2539        |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.004767063 |
# |    clip_fraction        | 0.0587      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.635      |
# |    explained_variance   | -0.534      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00132    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00347    |
# |    value_loss           | 1.38e-06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 259          |
# |    ep_rew_mean          | 0            |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 18           |
# |    time_elapsed         | 2544         |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0034171448 |
# |    clip_fraction        | 0.0445       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.692       |
# |    explained_variance   | -0.321       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00306     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00235     |
# |    value_loss           | 3.47e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 269          |
# |    ep_rew_mean          | 0            |
# | time/                   |              |
# |    fps                  | 15           |
# |    iterations           | 19           |
# |    time_elapsed         | 2550         |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0065365117 |
# |    clip_fraction        | 0.07         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.646       |
# |    explained_variance   | -4.08        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0113       |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00359     |
# |    value_loss           | 0.000429     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 275         |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 20          |
# |    time_elapsed         | 2556        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.004178857 |
# |    clip_fraction        | 0.0884      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.669      |
# |    explained_variance   | -1.04       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0176     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0081     |
# |    value_loss           | 1.96e-07    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 287        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 21         |
# |    time_elapsed         | 2562       |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.00592089 |
# |    clip_fraction        | 0.0526     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.694     |
# |    explained_variance   | -1.49      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00422    |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.00539   |
# |    value_loss           | 1.06e-07   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 299         |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 22          |
# |    time_elapsed         | 2569        |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.003134184 |
# |    clip_fraction        | 0.0351      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.694      |
# |    explained_variance   | -1.57       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.018      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00599    |
# |    value_loss           | 1.28e-07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 302          |
# |    ep_rew_mean          | 0            |
# | time/                   |              |
# |    fps                  | 18           |
# |    iterations           | 23           |
# |    time_elapsed         | 2575         |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0043456927 |
# |    clip_fraction        | 0.0618       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.593       |
# |    explained_variance   | -3.44        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0115       |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00388     |
# |    value_loss           | 7.66e-08     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 326         |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 24          |
# |    time_elapsed         | 2580        |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.004576641 |
# |    clip_fraction        | 0.0422      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.5        |
# |    explained_variance   | -3.14       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00409    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00101    |
# |    value_loss           | 1.55e-07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 326          |
# |    ep_rew_mean          | 0            |
# | time/                   |              |
# |    fps                  | 19           |
# |    iterations           | 25           |
# |    time_elapsed         | 2586         |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0068026897 |
# |    clip_fraction        | 0.0503       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.462       |
# |    explained_variance   | -1.47        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00477     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00533     |
# |    value_loss           | 0.000903     |
# ------------------------------------------
# Using cuda device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.36     |
# |    ep_rew_mean     | 0.01     |
# | time/              |          |
# |    fps             | 580      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 2
#       1 for map_ in maps:
# ----> 2     trained_model = train_ppo_on_map(maps[map_], total_timesteps=50000)
#       3     trained_model.save(f"ppo_frozenlake_{map_}")
#
# Cell In[23], line 43, in train_ppo_on_map(custom_map, total_timesteps, is_slippery, pretrained_model_path)
#      40     model = PPO("MlpPolicy", env, verbose=1)
#      42 # Train the model
# ---> 43 model.learn(total_timesteps=total_timesteps)
#      45 return model
#
# File c:\Users\patel\anaconda3\envs\llama\Lib\site-packages\stable_baselines3\ppo\ppo.py:315, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     306 def learn(
#     307     self: SelfPPO,
#     308     total_timesteps: int,
#    (...)
#     313     progress_bar: bool = False,
#     314 ) -> SelfPPO:
# --> 315     return super().learn(
#     316         total_timesteps=total_timesteps,
#     317         callback=callback,
#     318         log_interval=log_interval,
#     319         tb_log_name=tb_log_name,
#     320         reset_num_timesteps=reset_num_timesteps,
#     321         progress_bar=progress_bar,
#     322     )
#
# File c:\Users\patel\anaconda3\envs\llama\Lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:300, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     297 assert self.env is not None
#     299 while self.num_timesteps < total_timesteps:
# --> 300     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     302     if not continue_training:
#     303         break
#
# File c:\Users\patel\anaconda3\envs\llama\Lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:179, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     176 with th.no_grad():
#     177     # Convert to pytorch tensor or to TensorDict
#     178     obs_tensor = obs_as_tensor(self._last_obs, self.device)
# --> 179     actions, values, log_probs = self.policy(obs_tensor)
#     180 actions = actions.cpu().numpy()
#     182 # Rescale and perform action
#
# File c:\Users\patel\anaconda3\envs\llama\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\patel\anaconda3\envs\llama\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File c:\Users\patel\anaconda3\envs\llama\Lib\site-packages\stable_baselines3\common\policies.py:656, in ActorCriticPolicy.forward(self, obs, deterministic)
#     654 distribution = self._get_action_dist_from_latent(latent_pi)
#     655 actions = distribution.get_actions(deterministic=deterministic)
# --> 656 log_prob = distribution.log_prob(actions)
#     657 actions = actions.reshape((-1, *self.action_space.shape))  # type: ignore[misc]
#     658 return actions, values, log_prob
#
# File c:\Users\patel\anaconda3\envs\llama\Lib\site-packages\stable_baselines3\common\distributions.py:292, in CategoricalDistribution.log_prob(self, actions)
#     291 def log_prob(self, actions: th.Tensor) -> th.Tensor:
# --> 292     return self.distribution.log_prob(actions)
#
# File c:\Users\patel\anaconda3\envs\llama\Lib\site-packages\torch\distributions\categorical.py:140, in Categorical.log_prob(self, value)
#     138     self._validate_sample(value)
#     139 value = value.long().unsqueeze(-1)
# --> 140 value, log_pmf = torch.broadcast_tensors(value, self.logits)
#     141 value = value[..., :1]
#     142 return log_pmf.gather(-1, value).squeeze(-1)
#
# File c:\Users\patel\anaconda3\envs\llama\Lib\site-packages\torch\functional.py:77, in broadcast_tensors(*tensors)
#      75 if has_torch_function(tensors):
#      76     return handle_torch_function(broadcast_tensors, tensors, *tensors)
# ---> 77 return _VF.broadcast_tensors(tensors)
#
# KeyboardInterrupt:

# %%
import torch
def predict_action_probabilities(policy, states):
    """
    Predict action probabilities for each state using the given policy.
    
    :param policy: The policy network.
    :param states: List of states.
    :return: Action probabilities for each state.
    """
    action_probs = []
    for state in states:
        obs = torch.tensor([state], dtype=torch.float32, device=policy.device)
        action_dist = policy.policy.get_distribution(obs)
        action_probs.append(action_dist.distribution.probs.detach().cpu().numpy())
    return np.array(action_probs)

def KL_divergence(policy_net_1, policy_net_2, states):
    """
    Compute the KL divergence between two policies for a given state.
    
    :param policy_net_1: Policy network 1.
    :param policy_net_2: Policy network 2.
    :param states: State for which to compute the KL divergence.
    :return: average KL divergence between the two policies.
    """
    # Get the action probabilities for the two policies
    action_probs_1 = predict_action_probabilities(policy_net_1, states).squeeze()
    action_probs_2 = predict_action_probabilities(policy_net_2, states).squeeze()
    print(action_probs_1)
    print(action_probs_2)
    action_probs_1 = np.clip(action_probs_1, 1e-10, 1.0)
    action_probs_2 = np.clip(action_probs_2, 1e-10, 1.0)

    kl_divergence = np.sum(action_probs_1 * np.log(action_probs_1 / action_probs_2), axis=1)

    # Compute the KL divergence
    # print(kl_divergence.shape)
    return np.mean(kl_divergence)

def get_all_states(map_name):
    """
    Get all the states in the environment.
    
    :param env: Environment.
    :return: List of all states.
    """

    env = create_custom_env(map_name)
    all_states = np.arange(env.observation_space.n)
    return all_states

def get_all_states(map_name, input_st='large'):
    """
    Get all the states in the environment.
    
    :param env: Environment.
    :return: List of all states.
    """

    env = create_custom_env(map_name)
    base_ = env.state_without_agent
    all_states = []
    for i in range(len(base_)):
        if base_[i] == 0:
            n_ad = base_.copy()
            n_ad[i] = 1
            all_states.append(n_ad)
    return np.array(all_states)

# %%
import numpy as np
policy_1 = PPO.load("ppo_frozenlake_Map 2.1")
policy_2 = PPO.load("ppo_frozenlake_Map 2.2")
states = get_all_states(maps['Baseline'])

policies = {
    'Baseline': "ppo_frozenlake_Baseline",
    'Map 2.1':  "ppo_frozenlake_Map 2.1",
    'Map 2.2':  "ppo_frozenlake_Map 2.2",
    'Map 2.3':  "ppo_frozenlake_Map 2.3",
    'Map 3.1':  "ppo_frozenlake_Map 3.1",
    'Map 3.2':  "ppo_frozenlake_Map 3.2",
    'Map 3.3':  "ppo_frozenlake_Map 3.3",
    'Map 4.1':  "ppo_frozenlake_Map 4.1",
    'Map 4.2':  "ppo_frozenlake_Map 4.2",
    'Map 4.3':  "ppo_frozenlake_Map 4.3"
}

KL = {} #dictionary of dictionaries

for policy1 in policies:
    for policy2 in policies:
        if policy1 == policy2 or policy1 == 'Baseline' or policy2 == 'Baseline': continue
        if policy1 not in KL: KL[policy1] = {}
        policy_net_1 = PPO.load(policies[policy1])
        policy_net_2 = PPO.load(policies[policy2])
        kl_div = KL_divergence(policy_net_1, policy_net_2, states)
        KL[policy1][policy2] = kl_div
        print(f"KL Divergence between {policy1} and {policy2}: {kl_div:.4f}")
# Out:
# C:\Users\patel\AppData\Local\Temp\ipykernel_12308\4191513776.py:12: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\torch\csrc\utils\tensor_new.cpp:281.)
#   obs = torch.tensor([state], dtype=torch.float32, device=policy.device)
# [[0.48731953 0.0585381  0.4113563  0.04278607]
#  [0.48967266 0.05730338 0.4109015  0.04212256]
#  [0.48684686 0.05883747 0.41127428 0.04304139]
#  [0.49169934 0.05641292 0.41006723 0.04182051]
#  [0.48713234 0.05904303 0.41030407 0.04352045]
#  [0.48631883 0.05896634 0.41179577 0.04291908]
#  [0.48774248 0.05822591 0.41149148 0.04254014]
#  [0.487055   0.05856357 0.41167197 0.04270952]
#  [0.4876499  0.05849111 0.4109372  0.04292183]
#  [0.48878703 0.05791122 0.4107541  0.04254759]
#  [0.490506   0.05728731 0.40974095 0.04246583]]
# [[0.1775071  0.582194   0.04082894 0.19946991]
#  [0.18272805 0.56462705 0.04151898 0.21112594]
#  [0.18290667 0.5718236  0.04480426 0.20046547]
#  [0.6017494  0.20281217 0.0842225  0.11121589]]
# [[3.0208265e-02 3.1645872e-02 5.8549485e-04 9.3756044e-01]
#  [2.7443800e-02 2.9415738e-02 5.7760876e-04 9.4256276e-01]
#  [2.8144682e-02 2.9919205e-02 5.6797970e-04 9.4136816e-01]
#  [2.6611641e-02 2.8648105e-02 5.5935391e-04 9.4418085e-01]
#  [2.7630968e-02 2.9417360e-02 5.5295002e-04 9.4239867e-01]
#  [2.8286764e-02 2.9994749e-02 5.6359830e-04 9.4115496e-01]
#  [2.8177621e-02 2.9967412e-02 5.7284028e-04 9.4128221e-01]
#  [2.9970637e-02 3.1491976e-02 5.9310888e-04 9.3794429e-01]
#  [2.8206928e-02 2.9969608e-02 5.7006907e-04 9.4125348e-01]
#  [2.5443958e-02 2.7476979e-02 5.2036700e-04 9.4655871e-01]
#  [2.9825119e-02 3.1372376e-02 5.9214601e-04 9.3821031e-01]]
# KL Divergence between Map 4.3 and Map 4.2: 2.5226

# %%
m = train_ppo_on_map(maps['Map 3.1'], total_timesteps=50000)
# Out:
# c:\Users\patel\anaconda3\envs\llama\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Using cuda device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4.36     |
# |    ep_rew_mean     | 0        |
# | time/              |          |
# |    fps             | 570      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.32        |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 457         |
# |    iterations           | 2           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.022768017 |
# |    clip_fraction        | 0.25        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -23.9       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0734     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.024      |
# |    value_loss           | 0.00294     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.41        |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 432         |
# |    iterations           | 3           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.025376832 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | -0.0658     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0614     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0393     |
# |    value_loss           | 0.00211     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14.2        |
# |    ep_rew_mean          | 0.02        |
# | time/                   |             |
# |    fps                  | 422         |
# |    iterations           | 4           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.034112297 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.0424      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0166     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0118     |
# |    value_loss           | 0.00402     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17.4        |
# |    ep_rew_mean          | 0.1         |
# | time/                   |             |
# |    fps                  | 413         |
# |    iterations           | 5           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.021557722 |
# |    clip_fraction        | 0.248       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.0479      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00439    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.014      |
# |    value_loss           | 0.00723     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 17.5         |
# |    ep_rew_mean          | 0.23         |
# | time/                   |              |
# |    fps                  | 410          |
# |    iterations           | 6            |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0111973155 |
# |    clip_fraction        | 0.128        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 0.123        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0175      |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0221      |
# |    value_loss           | 0.0338       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16.2        |
# |    ep_rew_mean          | 0.38        |
# | time/                   |             |
# |    fps                  | 408         |
# |    iterations           | 7           |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.016108371 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.187       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0309     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0323     |
# |    value_loss           | 0.0662      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 13.2       |
# |    ep_rew_mean          | 0.58       |
# | time/                   |            |
# |    fps                  | 406        |
# |    iterations           | 8          |
# |    time_elapsed         | 40         |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.02005035 |
# |    clip_fraction        | 0.229      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.08      |
# |    explained_variance   | 0.138      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0245     |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.0369    |
# |    value_loss           | 0.0985     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.9        |
# |    ep_rew_mean          | 0.88        |
# | time/                   |             |
# |    fps                  | 405         |
# |    iterations           | 9           |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.025884578 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.957      |
# |    explained_variance   | 0.12        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.018       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0317     |
# |    value_loss           | 0.112       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.84        |
# |    ep_rew_mean          | 0.97        |
# | time/                   |             |
# |    fps                  | 402         |
# |    iterations           | 10          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.015617879 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.804      |
# |    explained_variance   | 0.113       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0202     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0298     |
# |    value_loss           | 0.0533      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.26        |
# |    ep_rew_mean          | 0.97        |
# | time/                   |             |
# |    fps                  | 400         |
# |    iterations           | 11          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.021566968 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.643      |
# |    explained_variance   | -0.126      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.012       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0203     |
# |    value_loss           | 0.0149      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.25       |
# |    ep_rew_mean          | 0.96       |
# | time/                   |            |
# |    fps                  | 399        |
# |    iterations           | 12         |
# |    time_elapsed         | 61         |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.02206067 |
# |    clip_fraction        | 0.233      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.462     |
# |    explained_variance   | 0.0144     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0593    |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.021     |
# |    value_loss           | 0.0113     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.7         |
# |    ep_rew_mean          | 0.99        |
# | time/                   |             |
# |    fps                  | 398         |
# |    iterations           | 13          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.014951514 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.325      |
# |    explained_variance   | 0.0508      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0255     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0209     |
# |    value_loss           | 0.0123      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.28        |
# |    ep_rew_mean          | 0.99        |
# | time/                   |             |
# |    fps                  | 396         |
# |    iterations           | 14          |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.018079989 |
# |    clip_fraction        | 0.062       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.195      |
# |    explained_variance   | 0.0198      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0322     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0153     |
# |    value_loss           | 0.00365     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.03        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 396         |
# |    iterations           | 15          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.038333975 |
# |    clip_fraction        | 0.0394      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0947     |
# |    explained_variance   | 0.0952      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00238     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0188     |
# |    value_loss           | 0.00354     |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 6.09          |
# |    ep_rew_mean          | 1             |
# | time/                   |               |
# |    fps                  | 395           |
# |    iterations           | 16            |
# |    time_elapsed         | 82            |
# |    total_timesteps      | 32768         |
# | train/                  |               |
# |    approx_kl            | 0.00041377795 |
# |    clip_fraction        | 0.00527       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.067        |
# |    explained_variance   | 0.932         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.000787      |
# |    n_updates            | 150           |
# |    policy_gradient_loss | -0.00299      |
# |    value_loss           | 7.71e-06      |
# -------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.04       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 395        |
# |    iterations           | 17         |
# |    time_elapsed         | 88         |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.00257011 |
# |    clip_fraction        | 0.0144     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0422    |
# |    explained_variance   | 0.938      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.000547  |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.0107    |
# |    value_loss           | 1.9e-05    |
# ----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 6.01          |
# |    ep_rew_mean          | 0.99          |
# | time/                   |               |
# |    fps                  | 395           |
# |    iterations           | 18            |
# |    time_elapsed         | 93            |
# |    total_timesteps      | 36864         |
# | train/                  |               |
# |    approx_kl            | 0.00045380899 |
# |    clip_fraction        | 0.00815       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0295       |
# |    explained_variance   | 0.957         |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.0161       |
# |    n_updates            | 170           |
# |    policy_gradient_loss | -0.00743      |
# |    value_loss           | 1.26e-05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.02         |
# |    ep_rew_mean          | 1            |
# | time/                   |              |
# |    fps                  | 395          |
# |    iterations           | 19           |
# |    time_elapsed         | 98           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0004245763 |
# |    clip_fraction        | 0.00435      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0219      |
# |    explained_variance   | 0.167        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000547     |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00484     |
# |    value_loss           | 0.00161      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.03         |
# |    ep_rew_mean          | 1            |
# | time/                   |              |
# |    fps                  | 394          |
# |    iterations           | 20           |
# |    time_elapsed         | 103          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0006669686 |
# |    clip_fraction        | 0.00264      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0139      |
# |    explained_variance   | 0.955        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000854    |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00284     |
# |    value_loss           | 3.2e-06      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 6             |
# |    ep_rew_mean          | 1             |
# | time/                   |               |
# |    fps                  | 394           |
# |    iterations           | 21            |
# |    time_elapsed         | 109           |
# |    total_timesteps      | 43008         |
# | train/                  |               |
# |    approx_kl            | 0.00021406321 |
# |    clip_fraction        | 0.00171       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00928      |
# |    explained_variance   | 0.995         |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.0169       |
# |    n_updates            | 200           |
# |    policy_gradient_loss | -0.00251      |
# |    value_loss           | 1.18e-06      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.01         |
# |    ep_rew_mean          | 1            |
# | time/                   |              |
# |    fps                  | 394          |
# |    iterations           | 22           |
# |    time_elapsed         | 114          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 3.073542e-05 |
# |    clip_fraction        | 0.000391     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0106      |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0035      |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00118     |
# |    value_loss           | 3.49e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6            |
# |    ep_rew_mean          | 1            |
# | time/                   |              |
# |    fps                  | 394          |
# |    iterations           | 23           |
# |    time_elapsed         | 119          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0009548506 |
# |    clip_fraction        | 0.00132      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0113      |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000661    |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00234     |
# |    value_loss           | 1.23e-06     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 6.03          |
# |    ep_rew_mean          | 1             |
# | time/                   |               |
# |    fps                  | 394           |
# |    iterations           | 24            |
# |    time_elapsed         | 124           |
# |    total_timesteps      | 49152         |
# | train/                  |               |
# |    approx_kl            | 0.00020605055 |
# |    clip_fraction        | 0.00127       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00713      |
# |    explained_variance   | 0.995         |
# |    learning_rate        | 0.0003        |
# |    loss                 | -1.71e-05     |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -0.0017       |
# |    value_loss           | 1.28e-06      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 6             |
# |    ep_rew_mean          | 1             |
# | time/                   |               |
# |    fps                  | 393           |
# |    iterations           | 25            |
# |    time_elapsed         | 130           |
# |    total_timesteps      | 51200         |
# | train/                  |               |
# |    approx_kl            | 0.00035919322 |
# |    clip_fraction        | 0.000879      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00489      |
# |    explained_variance   | 0.997         |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.000766     |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -0.00173      |
# |    value_loss           | 9.98e-07      |
# -------------------------------------------

# %%
generate_gif_from_policy(m, maps['Map 3.1'], gif_filename="ppo_frozenlake_map3.1.gif")
m.save("ppo_frozenlake_Map 3.1")
# Out:
# GIF saved as ppo_frozenlake_map3.1.gif
# c:\Users\patel\anaconda3\envs\llama\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# c:\Users\patel\anaconda3\envs\llama\Lib\site-packages\gym\utils\passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):

# %%
KL_divergence(PPO.load("ppo_frozenlake_Map 2.1"), m, states)
# Out:
# 1.5754921

# %%
import pprint, pandas as pd

# pprint.pprint(KL)
df = pd.DataFrame(KL)
row_to_move = df.loc['Map 2.1']

df = df.drop('Map 2.1')
df = pd.concat([row_to_move.to_frame().T, df])
df
# Out:
#           Map 2.1   Map 2.2   Map 2.3   Map 3.1   Map 3.2   Map 3.3   Map 4.1  \
# Map 2.1       NaN  1.361318  0.368706  1.276628  1.172743  0.860992  0.664351
# Map 2.2  1.223842       NaN  0.639736  0.888057  2.317672  3.088597  1.658128
# Map 2.3  0.291817  0.474352       NaN  0.661631  0.951929  0.961718  1.437313
# Map 3.1  1.246319  4.844479  1.963881       NaN  4.356048  2.945076  0.933580
# Map 3.2  3.450973  3.646537  2.978897  6.330189       NaN  1.322003  6.877470
# Map 3.3  3.783198  5.574817  3.468291  7.023938  1.520817       NaN  8.265690
# Map 4.1  1.803756  4.340181  3.165307  2.601337  5.514386  5.241910       NaN
# Map 4.2  4.005259  1.916686  2.895122  0.925905  6.287103  7.381369  3.511313
# Map 4.3  0.525706  0.541773  0.598490  0.871927  2.269004  2.696992  0.383287
#
#           Map 4.2   Map 4.3
# Map 2.1  2.808307  0.373867
# Map 2.2  1.314476  0.584761
# Map 2.3  1.287378  0.513904
# Map 3.1  0.573592  1.780362
# Map 3.2  7.421100  4.952004
# Map 3.3  7.936028  6.388093
# Map 4.1  5.145250  1.233147
# Map 4.2       NaN  2.522616
# Map 4.3  2.113011       NaN

# %%
for policy_ in policies:
    mod = PPO.load(policies[policy_])
    generate_gif_from_policy(mod, maps[policy_], gif_filename=f"./gifs/ppo_frozenlake_{policy_}.gif")
# Out:
# c:\Users\patel\anaconda3\envs\llama\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 3
#       1 for policy_ in policies:
#       2     mod = PPO.load(policies[policy_])
# ----> 3     generate_gif_from_policy(mod, maps[policy_], gif_filename=f"./gifs/ppo_frozenlake_{policy_}.gif")
#
# Cell In[25], line 19, in generate_gif_from_policy(model, custom_map, gif_filename, is_slippery)
#      17 for _ in range(100):  # Set a limit to prevent infinite loops
#      18     frames.append(env.render())
# ---> 19     action, _ = model.predict(obs)
#      20     obs, _, done, _ = env.step(action)
#      21     if done:
#
# File c:\Users\patel\anaconda3\envs\llama\Lib\site-packages\stable_baselines3\common\base_class.py:556, in BaseAlgorithm.predict(self, observation, state, episode_start, deterministic)
#     536 def predict(
#     537     self,
#     538     observation: Union[np.ndarray, Dict[str, np.ndarray]],
#    (...)
#     541     deterministic: bool = False,
#     542 ) -> Tuple[np.ndarray, Optional[Tuple[np.ndarray, ...]]]:
#     543     """
#     544     Get the policy action from an observation (and optional hidden state).
#     545     Includes sugar-coating to handle different observations (e.g. normalizing images).
#    (...)
#     554         (used in recurrent policies)
#     555     """
# --> 556     return self.policy.predict(observation, state, episode_start, deterministic)
#
# File c:\Users\patel\anaconda3\envs\llama\Lib\site-packages\stable_baselines3\common\policies.py:365, in BasePolicy.predict(self, observation, state, episode_start, deterministic)
#     356 if isinstance(observation, tuple) and len(observation) == 2 and isinstance(observation[1], dict):
#     357     raise ValueError(
#     358         "You have passed a tuple to the predict() function instead of a Numpy array or a Dict. "
#     359         "You are probably mixing Gym API with SB3 VecEnv API: `obs, info = env.reset()` (Gym) "
#    (...)
#     362         "and documentation for more information: https://stable-baselines3.readthedocs.io/en/master/guide/vec_envs.html#vecenv-api-vs-gym-api"
#     363     )
# --> 365 obs_tensor, vectorized_env = self.obs_to_tensor(observation)
#     367 with th.no_grad():
#     368     actions = self._predict(obs_tensor, deterministic=deterministic)
#
# File c:\Users\patel\anaconda3\envs\llama\Lib\site-packages\stable_baselines3\common\policies.py:272, in BaseModel.obs_to_tensor(self, observation)
#     268     observation = np.array(observation)
#     270 if not isinstance(observation, dict):
#     271     # Dict obs need to be handled separately
# --> 272     vectorized_env = is_vectorized_observation(observation, self.observation_space)
#     273     # Add batch dimension if needed
#     274     observation = observation.reshape((-1, *self.observation_space.shape))  # type: ignore[misc]
#
# File c:\Users\patel\anaconda3\envs\llama\Lib\site-packages\stable_baselines3\common\utils.py:401, in is_vectorized_observation(observation, observation_space)
#     399 for space_type, is_vec_obs_func in is_vec_obs_func_dict.items():
#     400     if isinstance(observation_space, space_type):
# --> 401         return is_vec_obs_func(observation, observation_space)  # type: ignore[operator]
#     402 else:
#     403     # for-else happens if no break is called
#     404     raise ValueError(f"Error: Cannot determine if the observation is vectorized with the space type {observation_space}.")
#
# File c:\Users\patel\anaconda3\envs\llama\Lib\site-packages\stable_baselines3\common\utils.py:268, in is_vectorized_box_observation(observation, observation_space)
#     266     return True
#     267 else:
# --> 268     raise ValueError(
#     269         f"Error: Unexpected observation shape {observation.shape} for "
#     270         + f"Box environment, please use {observation_space.shape} "
#     271         + "or (n_env, {}) for the observation shape.".format(", ".join(map(str, observation_space.shape)))
#     272     )
#
# ValueError: Error: Unexpected observation shape (1,) for Box environment, please use (16,) or (n_env, 16) for the observation shape.

# %%
import frozenlake_env
import importlib
importlib.reload(frozenlake_env)

from frozenlake_env import FrozenLakeEnv as FLEnv

env = FLEnv(desc=maps['Baseline'], is_slippery=False)
env.observation_space.n

env.seed
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[34], line 10
#       7 env = FLEnv(desc=maps['Baseline'], is_slippery=False)
#       8 env.observation_space.n
# ---> 10 env.seed
#
# AttributeError: 'FrozenLakeEnv' object has no attribute 'seed'

# %%
from gym.envs.toy_text.frozen_lake import FrozenLakeEnv

env = FrozenLakeEnv(desc=maps['Baseline'], is_slippery=False)
env.seed
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 4
#       1 from gym.envs.toy_text.frozen_lake import FrozenLakeEnv
#       3 env = FrozenLakeEnv(desc=maps['Baseline'], is_slippery=False)
# ----> 4 env.seed
#
# AttributeError: 'FrozenLakeEnv' object has no attribute 'seed'
